# %%
# ====== Imports ======
import os, random
import numpy as np
import pandas as pd
from scipy.stats import iqr
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# ====== Imports ======
import os, random
import numpy as np
import pandas as pd
from scipy.stats import iqr
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# ====== Colab drive mount ======
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Path to the zip file in Colab
zip_file_path = '/content/MTF_train_65x65.zip'

# Directory to extract to
extract_to = '/content/MTVs/'

# Unzipping the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"File unzipped to {extract_to}")
# Out:
# File unzipped to /content/MTVs/

# %%
# ====== Paths ======
IMG_DIR = "/content/MTVs"
CSV_PATH = "/content/train_df_averaged.csv"

TARGETS = ['Moi','NDF',  'Starch']
IMG_SIZE = 65 #------------------------------------------>16

# %%
# ====== Hyperparams ======
batch_size = 128
epochs = 200
lr = 0.0001
n_splits = 5
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
# ====== Load CSV ======
df = pd.read_csv(CSV_PATH)
# df = df.groupby('Sample ID').mean() # If the data is not averaged
# df = df.dropna(subset=TARGETS).reset_index(drop=True)
print("Data shape:", df.shape)
# Out:
# Data shape: (784, 261)

# %%
# ====== Scale targets ======
from sklearn.preprocessing import StandardScaler
# y_scaler = MinMaxScaler()
y_scaler = StandardScaler() # => Auto scale
targets_scaled = y_scaler.fit_transform(df[TARGETS].values.astype(np.float32))

# %%
plot_name = "sample"  # Change this based on the plot type

# %%
# ====== Dataset class (images already ready) ======

class SoilImageDataset(Dataset):
    def __init__(self, df, img_dir, targets_scaled, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.targets = targets_scaled.astype(np.float32)
        self.transform = transform if transform else transforms.ToTensor()

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, f"{plot_name}_{idx}.png")
        # Add a check to see if the image file exists
        if not os.path.exists(img_path):
            print(f"Error: Image file not found at {img_path} for index {idx}")
            # You might want to raise an error or handle this case differently
            # For now, we'll just print and continue, which might lead to subsequent errors
            # depending on how the DataLoader handles missing items.
            # A better approach might be to filter the DataFrame beforehand.
            raise FileNotFoundError(f"Image file not found at {img_path}") # Raising error to stop execution and show the path
        img = Image.open(img_path).convert("L").resize((IMG_SIZE, IMG_SIZE))  # grayscale
        img = self.transform(img)  # shape (1,H,W)
        target = torch.from_numpy(self.targets[idx])
        return img, target

transform = transforms.Compose([
    transforms.ToTensor(),  # (H,W) -> (1,H,W), float in [0,1]
])

dataset = SoilImageDataset(df, IMG_DIR, targets_scaled, transform=transform)
print("Dataset length:", len(dataset))
# Out:
# Dataset length: 784

# %%
# ====== CNN model (as in Table 2) ======
class CNN2D(nn.Module):
    def __init__(self, in_channels=1, num_outputs=3): # Changed num_outputs to 3
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3a = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, 3, padding=1)
        self.conv4a = nn.Conv2d(256, 512, 3, padding=1)
        self.conv4b = nn.Conv2d(512, 512, 3, padding=1)
        self.conv5a = nn.Conv2d(512, 512, 3, padding=1)
        self.conv5b = nn.Conv2d(512, 512, 3, padding=1)

        self.flattened = 512 * 2 * 2
        self.fc1 = nn.Linear(self.flattened, 128)
        self.fc2 = nn.Linear(128, num_outputs)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x)); x = self.pool(x)
        x = self.relu(self.conv2(x)); x = self.pool(x)
        x = self.relu(self.conv3a(x)); x = self.relu(self.conv3b(x)); x = self.pool(x)
        x = self.relu(self.conv4a(x)); x = self.relu(self.conv4b(x)); x = self.pool(x)
        x = self.relu(self.conv5a(x)); x = self.relu(self.conv5b(x)); x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        return self.fc2(x)

# %%
# ====== Metrics ======
def compute_metrics_orig(y_true, y_pred):
    results = []
    for i in range(y_true.shape[1]):
        yt, yp = y_true[:, i], y_pred[:, i]
        rmse = np.sqrt(mean_squared_error(yt, yp))
        r2 = r2_score(yt, yp)
        rpiq = float(iqr(yt) / rmse) if rmse > 1e-8 else float("inf")
        results.append({"RMSE": rmse, "R2": r2, "RPIQ": rpiq})
    return results

# %%
# ====== Split train/test ======
indices = np.arange(len(dataset))
trainval_idx, test_idx = train_test_split(indices, test_size=0.25, random_state=seed)

# %%
# ====== 5-Fold CV ====== But more Verbose
kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
for fold, (t_idx, v_idx) in enumerate(kf.split(trainval_idx)):
    print(f"\n--- Fold {fold+1}/{n_splits} ---")
    train_loader = DataLoader(Subset(dataset, trainval_idx[t_idx]), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(Subset(dataset, trainval_idx[v_idx]), batch_size=batch_size, shuffle=False)

    model = CNN2D().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    for epoch in range(epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            loss = criterion(model(xb), yb)
            loss.backward()
            optimizer.step()

        # Verbose mode
        if (epoch+1) % 1 == 0:  # This will print every epoch (verbose=2 equivalent in training)
            print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")

    # Validation
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            preds = model(xb.to(device)).cpu().numpy()
            yb_np = yb.cpu().numpy()
            preds_orig = y_scaler.inverse_transform(preds)
            yb_orig = y_scaler.inverse_transform(yb_np)
            y_true.append(yb_orig); y_pred.append(preds_orig)
    y_true, y_pred = np.vstack(y_true), np.vstack(y_pred)

    # Compute and print metrics
    metrics = compute_metrics_orig(y_true, y_pred)
    for i, t in enumerate(TARGETS):
        print(f"{t}: RMSE={metrics[i]['RMSE']:.3f}, R2={metrics[i]['R2']:.3f}, RPIQ={metrics[i]['RPIQ']:.3f}")
# Out:
# --- Fold 1/5 ---
# Epoch 1/200, Loss: 1.1221
# Epoch 2/200, Loss: 0.8392
# Epoch 3/200, Loss: 1.1362
# Epoch 4/200, Loss: 0.9699
# Epoch 5/200, Loss: 0.9405
# Epoch 6/200, Loss: 0.8293
# Epoch 7/200, Loss: 1.0344
# Epoch 8/200, Loss: 1.0219
# Epoch 9/200, Loss: 0.8750
# Epoch 10/200, Loss: 1.4944
# Epoch 11/200, Loss: 1.0299
# Epoch 12/200, Loss: 0.7579
# Epoch 13/200, Loss: 1.2103
# Epoch 14/200, Loss: 0.9300
# Epoch 15/200, Loss: 0.9873
# Epoch 16/200, Loss: 0.9056
# Epoch 17/200, Loss: 0.9027
# Epoch 18/200, Loss: 0.9566
# Epoch 19/200, Loss: 0.9668
# Epoch 20/200, Loss: 0.6304
# Epoch 21/200, Loss: 0.6281
# Epoch 22/200, Loss: 0.5818
# Epoch 23/200, Loss: 0.5311
# Epoch 24/200, Loss: 0.5894
# Epoch 25/200, Loss: 0.6690
# Epoch 26/200, Loss: 0.5911
# Epoch 27/200, Loss: 0.6084
# Epoch 28/200, Loss: 0.8755
# Epoch 29/200, Loss: 0.4668
# Epoch 30/200, Loss: 0.6043
# Epoch 31/200, Loss: 0.5658
# Epoch 32/200, Loss: 0.6462
# Epoch 33/200, Loss: 0.5717
# Epoch 34/200, Loss: 0.6243
# Epoch 35/200, Loss: 0.7078
# Epoch 36/200, Loss: 0.8678
# Epoch 37/200, Loss: 0.6282
# Epoch 38/200, Loss: 0.3934
# Epoch 39/200, Loss: 0.8190
# Epoch 40/200, Loss: 0.5039
# Epoch 41/200, Loss: 0.5059
# Epoch 42/200, Loss: 0.5137
# Epoch 43/200, Loss: 0.5161
# Epoch 44/200, Loss: 0.6034
# Epoch 45/200, Loss: 0.5454
# Epoch 46/200, Loss: 0.8841
# Epoch 47/200, Loss: 0.7062
# Epoch 48/200, Loss: 0.4696
# Epoch 49/200, Loss: 0.4291
# Epoch 50/200, Loss: 0.8147
# Epoch 51/200, Loss: 0.4316
# Epoch 52/200, Loss: 0.5258
# Epoch 53/200, Loss: 0.7537
# Epoch 54/200, Loss: 0.4664
# Epoch 55/200, Loss: 0.6486
# Epoch 56/200, Loss: 0.7662
# Epoch 57/200, Loss: 0.5390
# Epoch 58/200, Loss: 0.5148
# Epoch 59/200, Loss: 0.5017
# Epoch 60/200, Loss: 0.5311
# Epoch 61/200, Loss: 0.5422
# Epoch 62/200, Loss: 0.4311
# Epoch 63/200, Loss: 0.7163
# Epoch 64/200, Loss: 0.3975
# Epoch 65/200, Loss: 0.7183
# Epoch 66/200, Loss: 0.4179
# Epoch 67/200, Loss: 0.5277
# Epoch 68/200, Loss: 0.4650
# Epoch 69/200, Loss: 0.7291
# Epoch 70/200, Loss: 0.4186
# Epoch 71/200, Loss: 0.4980
# Epoch 72/200, Loss: 0.6331
# Epoch 73/200, Loss: 0.5270
# Epoch 74/200, Loss: 0.3693
# Epoch 75/200, Loss: 0.5321
# Epoch 76/200, Loss: 0.4638
# Epoch 77/200, Loss: 0.4120
# Epoch 78/200, Loss: 0.4230
# Epoch 79/200, Loss: 0.5442
# Epoch 80/200, Loss: 0.3836
# Epoch 81/200, Loss: 0.6532
# Epoch 82/200, Loss: 0.5456
# Epoch 83/200, Loss: 0.4675
# Epoch 84/200, Loss: 0.4081
# Epoch 85/200, Loss: 0.4489
# Epoch 86/200, Loss: 0.3789
# Epoch 87/200, Loss: 0.3968
# Epoch 88/200, Loss: 0.3836
# Epoch 89/200, Loss: 0.3468
# Epoch 90/200, Loss: 0.3544
# Epoch 91/200, Loss: 0.4612
# Epoch 92/200, Loss: 0.4573
# Epoch 93/200, Loss: 0.7055
# Epoch 94/200, Loss: 0.6475
# Epoch 95/200, Loss: 0.3416
# Epoch 96/200, Loss: 0.4069
# Epoch 97/200, Loss: 0.6421
# Epoch 98/200, Loss: 0.3336
# Epoch 99/200, Loss: 0.4838
# Epoch 100/200, Loss: 0.6276
# Epoch 101/200, Loss: 0.6430
# Epoch 102/200, Loss: 0.4116
# Epoch 103/200, Loss: 0.4194
# Epoch 104/200, Loss: 0.3224
# Epoch 105/200, Loss: 0.3438
# Epoch 106/200, Loss: 0.3825
# Epoch 107/200, Loss: 0.3193
# Epoch 108/200, Loss: 0.3437
# Epoch 109/200, Loss: 0.3979
# Epoch 110/200, Loss: 0.4304
# Epoch 111/200, Loss: 0.3624
# Epoch 112/200, Loss: 0.3673
# Epoch 113/200, Loss: 0.3535
# Epoch 114/200, Loss: 0.4311
# Epoch 115/200, Loss: 0.3514
# Epoch 116/200, Loss: 0.5800
# Epoch 117/200, Loss: 0.3982
# Epoch 118/200, Loss: 0.5753
# Epoch 119/200, Loss: 0.3623
# Epoch 120/200, Loss: 0.3531
# Epoch 121/200, Loss: 0.3487
# Epoch 122/200, Loss: 0.3425
# Epoch 123/200, Loss: 0.3491
# Epoch 124/200, Loss: 0.6378
# Epoch 125/200, Loss: 0.4387
# Epoch 126/200, Loss: 0.3446
# Epoch 127/200, Loss: 0.5708
# Epoch 128/200, Loss: 0.3870
# Epoch 129/200, Loss: 0.4159
# Epoch 130/200, Loss: 0.3863
# Epoch 131/200, Loss: 0.3659
# Epoch 132/200, Loss: 0.3308
# Epoch 133/200, Loss: 0.5649
# Epoch 134/200, Loss: 0.5451
# Epoch 135/200, Loss: 0.4433
# Epoch 136/200, Loss: 0.3977
# Epoch 137/200, Loss: 0.6461
# Epoch 138/200, Loss: 0.3773
# Epoch 139/200, Loss: 0.4230
# Epoch 140/200, Loss: 0.2488
# Epoch 141/200, Loss: 0.4044
# Epoch 142/200, Loss: 0.4631
# Epoch 143/200, Loss: 0.3564
# Epoch 144/200, Loss: 0.4758
# Epoch 145/200, Loss: 0.3740
# Epoch 146/200, Loss: 0.3332
# Epoch 147/200, Loss: 0.3538
# Epoch 148/200, Loss: 0.3504
# Epoch 149/200, Loss: 0.3314
# Epoch 150/200, Loss: 0.4189
# Epoch 151/200, Loss: 0.5948
# Epoch 152/200, Loss: 0.2977
# Epoch 153/200, Loss: 0.6605
# Epoch 154/200, Loss: 0.4987
# Epoch 155/200, Loss: 0.3486
# Epoch 156/200, Loss: 0.5617
# Epoch 157/200, Loss: 0.3465
# Epoch 158/200, Loss: 0.2983
# Epoch 159/200, Loss: 0.3341
# Epoch 160/200, Loss: 0.3032
# Epoch 161/200, Loss: 0.3194
# Epoch 162/200, Loss: 0.3836
# Epoch 163/200, Loss: 0.3246
# Epoch 164/200, Loss: 0.3356
# Epoch 165/200, Loss: 0.3251
# Epoch 166/200, Loss: 0.3175
# Epoch 167/200, Loss: 0.3255
# Epoch 168/200, Loss: 0.3112
# Epoch 169/200, Loss: 0.3496
# Epoch 170/200, Loss: 0.3350
# Epoch 171/200, Loss: 0.3845
# Epoch 172/200, Loss: 0.5986
# Epoch 173/200, Loss: 0.5348
# Epoch 174/200, Loss: 0.2865
# Epoch 175/200, Loss: 0.3256
# Epoch 176/200, Loss: 0.3417
# Epoch 177/200, Loss: 0.3343
# Epoch 178/200, Loss: 0.3276
# Epoch 179/200, Loss: 0.3050
# Epoch 180/200, Loss: 0.2616
# Epoch 181/200, Loss: 0.4031
# Epoch 182/200, Loss: 0.2991
# Epoch 183/200, Loss: 0.2813
# Epoch 184/200, Loss: 0.4846
# Epoch 185/200, Loss: 0.2876
# Epoch 186/200, Loss: 0.2384
# Epoch 187/200, Loss: 0.2875
# Epoch 188/200, Loss: 0.5126
# Epoch 189/200, Loss: 0.3228
# Epoch 190/200, Loss: 0.3659
# Epoch 191/200, Loss: 0.2739
# Epoch 192/200, Loss: 0.3289
# Epoch 193/200, Loss: 0.5002
# Epoch 194/200, Loss: 0.2458
# Epoch 195/200, Loss: 0.2979
# Epoch 196/200, Loss: 0.2908
# Epoch 197/200, Loss: 0.3430
# Epoch 198/200, Loss: 0.2664
# Epoch 199/200, Loss: 0.3578
# Epoch 200/200, Loss: 0.2378
# Moi: RMSE=4.017, R2=0.595, RPIQ=1.687
# NDF: RMSE=5.223, R2=0.288, RPIQ=1.655
# Starch: RMSE=7.803, R2=0.409, RPIQ=1.392
#
# --- Fold 2/5 ---
# Epoch 1/200, Loss: 0.8337
# Epoch 2/200, Loss: 1.0414
# Epoch 3/200, Loss: 1.2875
# Epoch 4/200, Loss: 0.9709
# Epoch 5/200, Loss: 0.7052
# Epoch 6/200, Loss: 1.1182
# Epoch 7/200, Loss: 1.0246
# Epoch 8/200, Loss: 1.1792
# Epoch 9/200, Loss: 1.3722
# Epoch 10/200, Loss: 0.7468
# Epoch 11/200, Loss: 0.7328
# Epoch 12/200, Loss: 1.2258
# Epoch 13/200, Loss: 0.8429
# Epoch 14/200, Loss: 1.3722
# Epoch 15/200, Loss: 0.9147
# Epoch 16/200, Loss: 0.7437
# Epoch 17/200, Loss: 1.5175
# Epoch 18/200, Loss: 1.0961
# Epoch 19/200, Loss: 0.9487
# Epoch 20/200, Loss: 0.7833
# Epoch 21/200, Loss: 0.8869
# Epoch 22/200, Loss: 1.0407
# Epoch 23/200, Loss: 0.6243
# Epoch 24/200, Loss: 1.0435
# Epoch 25/200, Loss: 0.9076
# Epoch 26/200, Loss: 0.6997
# Epoch 27/200, Loss: 0.7542
# Epoch 28/200, Loss: 1.0648
# Epoch 29/200, Loss: 0.6974
# Epoch 30/200, Loss: 0.6571
# Epoch 31/200, Loss: 0.8184
# Epoch 32/200, Loss: 0.6237
# Epoch 33/200, Loss: 0.9875
# Epoch 34/200, Loss: 0.7008
# Epoch 35/200, Loss: 0.5216
# Epoch 36/200, Loss: 0.4977
# Epoch 37/200, Loss: 0.8718
# Epoch 38/200, Loss: 0.6170
# Epoch 39/200, Loss: 0.6681
# Epoch 40/200, Loss: 0.6116
# Epoch 41/200, Loss: 0.5697
# Epoch 42/200, Loss: 0.5011
# Epoch 43/200, Loss: 0.6917
# Epoch 44/200, Loss: 0.6980
# Epoch 45/200, Loss: 0.5536
# Epoch 46/200, Loss: 0.5669
# Epoch 47/200, Loss: 0.5832
# Epoch 48/200, Loss: 0.7068
# Epoch 49/200, Loss: 0.5179
# Epoch 50/200, Loss: 0.7632
# Epoch 51/200, Loss: 0.4857
# Epoch 52/200, Loss: 0.7427
# Epoch 53/200, Loss: 0.6165
# Epoch 54/200, Loss: 0.4729
# Epoch 55/200, Loss: 0.5880
# Epoch 56/200, Loss: 0.7304
# Epoch 57/200, Loss: 0.4778
# Epoch 58/200, Loss: 0.6634
# Epoch 59/200, Loss: 0.5234
# Epoch 60/200, Loss: 0.3954
# Epoch 61/200, Loss: 0.5999
# Epoch 62/200, Loss: 0.4781
# Epoch 63/200, Loss: 0.5368
# Epoch 64/200, Loss: 0.6284
# Epoch 65/200, Loss: 0.5177
# Epoch 66/200, Loss: 0.5546
# Epoch 67/200, Loss: 0.5988
# Epoch 68/200, Loss: 0.4566
# Epoch 69/200, Loss: 0.5221
# Epoch 70/200, Loss: 0.4286
# Epoch 71/200, Loss: 0.3964
# Epoch 72/200, Loss: 0.5071
# Epoch 73/200, Loss: 0.6289
# Epoch 74/200, Loss: 0.4797
# Epoch 75/200, Loss: 0.5397
# Epoch 76/200, Loss: 0.3932
# Epoch 77/200, Loss: 0.4197
# Epoch 78/200, Loss: 0.4094
# Epoch 79/200, Loss: 0.4202
# Epoch 80/200, Loss: 0.6558
# Epoch 81/200, Loss: 0.5225
# Epoch 82/200, Loss: 0.6842
# Epoch 83/200, Loss: 0.4390
# Epoch 84/200, Loss: 0.6811
# Epoch 85/200, Loss: 0.3715
# Epoch 86/200, Loss: 0.6970
# Epoch 87/200, Loss: 0.3919
# Epoch 88/200, Loss: 0.5535
# Epoch 89/200, Loss: 0.3650
# Epoch 90/200, Loss: 0.3418
# Epoch 91/200, Loss: 0.5057
# Epoch 92/200, Loss: 0.6021
# Epoch 93/200, Loss: 0.4205
# Epoch 94/200, Loss: 0.3485
# Epoch 95/200, Loss: 0.2732
# Epoch 96/200, Loss: 0.3401
# Epoch 97/200, Loss: 0.4799
# Epoch 98/200, Loss: 0.3517
# Epoch 99/200, Loss: 0.3515
# Epoch 100/200, Loss: 0.4540
# Epoch 101/200, Loss: 0.6516
# Epoch 102/200, Loss: 0.6009
# Epoch 103/200, Loss: 0.5168
# Epoch 104/200, Loss: 0.4051
# Epoch 105/200, Loss: 0.3587
# Epoch 106/200, Loss: 0.5334
# Epoch 107/200, Loss: 0.5643
# Epoch 108/200, Loss: 0.3859
# Epoch 109/200, Loss: 0.4006
# Epoch 110/200, Loss: 0.3592
# Epoch 111/200, Loss: 0.4217
# Epoch 112/200, Loss: 0.3009
# Epoch 113/200, Loss: 0.3314
# Epoch 114/200, Loss: 0.4503
# Epoch 115/200, Loss: 0.3510
# Epoch 116/200, Loss: 0.3439
# Epoch 117/200, Loss: 0.5471
# Epoch 118/200, Loss: 0.2741
# Epoch 119/200, Loss: 0.4792
# Epoch 120/200, Loss: 0.4800
# Epoch 121/200, Loss: 0.6442
# Epoch 122/200, Loss: 0.5739
# Epoch 123/200, Loss: 0.3896
# Epoch 124/200, Loss: 0.2979
# Epoch 125/200, Loss: 0.5309
# Epoch 126/200, Loss: 0.4062
# Epoch 127/200, Loss: 0.2828
# Epoch 128/200, Loss: 0.3276
# Epoch 129/200, Loss: 0.3646
# Epoch 130/200, Loss: 0.3181
# Epoch 131/200, Loss: 0.3902
# Epoch 132/200, Loss: 0.3112
# Epoch 133/200, Loss: 0.5140
# Epoch 134/200, Loss: 0.5628
# Epoch 135/200, Loss: 0.3184
# Epoch 136/200, Loss: 0.5913
# Epoch 137/200, Loss: 0.2806
# Epoch 138/200, Loss: 0.3345
# Epoch 139/200, Loss: 0.3241
# Epoch 140/200, Loss: 0.3035
# Epoch 141/200, Loss: 0.3155
# Epoch 142/200, Loss: 0.3681
# Epoch 143/200, Loss: 0.2716
# Epoch 144/200, Loss: 0.4157
# Epoch 145/200, Loss: 0.3677
# Epoch 146/200, Loss: 0.5699
# Epoch 147/200, Loss: 0.3656
# Epoch 148/200, Loss: 0.3536
# Epoch 149/200, Loss: 0.3437
# Epoch 150/200, Loss: 0.3080
# Epoch 151/200, Loss: 0.3563
# Epoch 152/200, Loss: 0.4917
# Epoch 153/200, Loss: 0.3486
# Epoch 154/200, Loss: 0.2716
# Epoch 155/200, Loss: 0.3863
# Epoch 156/200, Loss: 0.3210
# Epoch 157/200, Loss: 0.5495
# Epoch 158/200, Loss: 0.3199
# Epoch 159/200, Loss: 0.3200
# Epoch 160/200, Loss: 0.3346
# Epoch 161/200, Loss: 0.3758
# Epoch 162/200, Loss: 0.3503
# Epoch 163/200, Loss: 0.3710
# Epoch 164/200, Loss: 0.2690
# Epoch 165/200, Loss: 0.3151
# Epoch 166/200, Loss: 0.4910
# Epoch 167/200, Loss: 0.2801
# Epoch 168/200, Loss: 0.3271
# Epoch 169/200, Loss: 0.3221
# Epoch 170/200, Loss: 0.2887
# Epoch 171/200, Loss: 0.3077
# Epoch 172/200, Loss: 0.2951
# Epoch 173/200, Loss: 0.2686
# Epoch 174/200, Loss: 0.3395
# Epoch 175/200, Loss: 0.5328
# Epoch 176/200, Loss: 0.4705
# Epoch 177/200, Loss: 0.3036
# Epoch 178/200, Loss: 0.2338
# Epoch 179/200, Loss: 0.3211
# Epoch 180/200, Loss: 0.5881
# Epoch 181/200, Loss: 0.3096
# Epoch 182/200, Loss: 0.2805
# Epoch 183/200, Loss: 0.2542
# Epoch 184/200, Loss: 0.3403
# Epoch 185/200, Loss: 0.2415
# Epoch 186/200, Loss: 0.3110
# Epoch 187/200, Loss: 0.3066
# Epoch 188/200, Loss: 0.6296
# Epoch 189/200, Loss: 0.2919
# Epoch 190/200, Loss: 0.3667
# Epoch 191/200, Loss: 0.3768
# Epoch 192/200, Loss: 0.2448
# Epoch 193/200, Loss: 0.3412
# Epoch 194/200, Loss: 0.4077
# Epoch 195/200, Loss: 0.3054
# Epoch 196/200, Loss: 0.6169
# Epoch 197/200, Loss: 0.3762
# Epoch 198/200, Loss: 0.3153
# Epoch 199/200, Loss: 0.2623
# Epoch 200/200, Loss: 0.2353
# Moi: RMSE=4.080, R2=0.478, RPIQ=1.893
# NDF: RMSE=5.390, R2=0.180, RPIQ=1.485
# Starch: RMSE=7.788, R2=0.358, RPIQ=1.354
#
# --- Fold 3/5 ---
# Epoch 1/200, Loss: 1.0841
# Epoch 2/200, Loss: 1.0998
# Epoch 3/200, Loss: 1.3264
# Epoch 4/200, Loss: 0.8643
# Epoch 5/200, Loss: 0.9323
# Epoch 6/200, Loss: 0.7496
# Epoch 7/200, Loss: 0.7961
# Epoch 8/200, Loss: 0.7382
# Epoch 9/200, Loss: 0.9298
# Epoch 10/200, Loss: 0.8342
# Epoch 11/200, Loss: 0.8465
# Epoch 12/200, Loss: 0.6960
# Epoch 13/200, Loss: 0.9132
# Epoch 14/200, Loss: 1.2228
# Epoch 15/200, Loss: 1.0713
# Epoch 16/200, Loss: 0.8924
# Epoch 17/200, Loss: 1.0879
# Epoch 18/200, Loss: 0.9003
# Epoch 19/200, Loss: 1.1162
# Epoch 20/200, Loss: 0.9038
# Epoch 21/200, Loss: 0.9227
# Epoch 22/200, Loss: 1.1564
# Epoch 23/200, Loss: 0.9037
# Epoch 24/200, Loss: 1.1992
# Epoch 25/200, Loss: 1.1280
# Epoch 26/200, Loss: 0.8079
# Epoch 27/200, Loss: 0.6993
# Epoch 28/200, Loss: 0.8127
# Epoch 29/200, Loss: 0.8911
# Epoch 30/200, Loss: 0.6799
# Epoch 31/200, Loss: 0.6388
# Epoch 32/200, Loss: 0.6580
# Epoch 33/200, Loss: 0.6681
# Epoch 34/200, Loss: 1.0546
# Epoch 35/200, Loss: 0.5166
# Epoch 36/200, Loss: 0.6630
# Epoch 37/200, Loss: 0.5990
# Epoch 38/200, Loss: 0.5646
# Epoch 39/200, Loss: 0.5963
# Epoch 40/200, Loss: 0.4697
# Epoch 41/200, Loss: 0.5105
# Epoch 42/200, Loss: 0.6284
# Epoch 43/200, Loss: 0.8586
# Epoch 44/200, Loss: 0.8416
# Epoch 45/200, Loss: 0.6851
# Epoch 46/200, Loss: 0.5378
# Epoch 47/200, Loss: 0.8389
# Epoch 48/200, Loss: 0.8585
# Epoch 49/200, Loss: 0.5797
# Epoch 50/200, Loss: 0.5249
# Epoch 51/200, Loss: 0.4731
# Epoch 52/200, Loss: 0.4945
# Epoch 53/200, Loss: 0.4780
# Epoch 54/200, Loss: 0.8216
# Epoch 55/200, Loss: 0.5047
# Epoch 56/200, Loss: 0.6294
# Epoch 57/200, Loss: 0.7229
# Epoch 58/200, Loss: 0.8261
# Epoch 59/200, Loss: 0.5219
# Epoch 60/200, Loss: 0.5133
# Epoch 61/200, Loss: 0.7019
# Epoch 62/200, Loss: 0.6512
# Epoch 63/200, Loss: 0.4797
# Epoch 64/200, Loss: 0.5713
# Epoch 65/200, Loss: 0.4300
# Epoch 66/200, Loss: 0.5007
# Epoch 67/200, Loss: 0.6955
# Epoch 68/200, Loss: 0.5888
# Epoch 69/200, Loss: 0.5311
# Epoch 70/200, Loss: 0.5249
# Epoch 71/200, Loss: 0.6846
# Epoch 72/200, Loss: 0.5288
# Epoch 73/200, Loss: 0.4543
# Epoch 74/200, Loss: 0.6436
# Epoch 75/200, Loss: 0.3307
# Epoch 76/200, Loss: 0.5002
# Epoch 77/200, Loss: 0.4519
# Epoch 78/200, Loss: 0.3528
# Epoch 79/200, Loss: 0.4498
# Epoch 80/200, Loss: 0.4735
# Epoch 81/200, Loss: 0.5092
# Epoch 82/200, Loss: 0.4213
# Epoch 83/200, Loss: 0.7180
# Epoch 84/200, Loss: 0.4160
# Epoch 85/200, Loss: 0.4930
# Epoch 86/200, Loss: 0.4478
# Epoch 87/200, Loss: 0.3486
# Epoch 88/200, Loss: 0.3979
# Epoch 89/200, Loss: 0.4837
# Epoch 90/200, Loss: 0.6826
# Epoch 91/200, Loss: 0.3635
# Epoch 92/200, Loss: 0.4071
# Epoch 93/200, Loss: 0.4237
# Epoch 94/200, Loss: 0.6636
# Epoch 95/200, Loss: 0.4402
# Epoch 96/200, Loss: 0.6384
# Epoch 97/200, Loss: 0.5097
# Epoch 98/200, Loss: 0.5733
# Epoch 99/200, Loss: 0.3721
# Epoch 100/200, Loss: 0.4004
# Epoch 101/200, Loss: 0.4802
# Epoch 102/200, Loss: 0.3596
# Epoch 103/200, Loss: 0.3756
# Epoch 104/200, Loss: 0.4131
# Epoch 105/200, Loss: 0.4653
# Epoch 106/200, Loss: 0.4120
# Epoch 107/200, Loss: 0.3856
# Epoch 108/200, Loss: 0.4528
# Epoch 109/200, Loss: 0.4073
# Epoch 110/200, Loss: 0.3489
# Epoch 111/200, Loss: 0.4148
# Epoch 112/200, Loss: 0.3915
# Epoch 113/200, Loss: 0.4751
# Epoch 114/200, Loss: 0.4951
# Epoch 115/200, Loss: 0.4039
# Epoch 116/200, Loss: 0.4523
# Epoch 117/200, Loss: 0.4089
# Epoch 118/200, Loss: 0.3752
# Epoch 119/200, Loss: 0.3394
# Epoch 120/200, Loss: 0.4367
# Epoch 121/200, Loss: 0.3982
# Epoch 122/200, Loss: 0.2874
# Epoch 123/200, Loss: 0.3983
# Epoch 124/200, Loss: 0.3500
# Epoch 125/200, Loss: 0.5677
# Epoch 126/200, Loss: 0.3271
# Epoch 127/200, Loss: 0.3742
# Epoch 128/200, Loss: 0.3474
# Epoch 129/200, Loss: 0.3360
# Epoch 130/200, Loss: 0.3882
# Epoch 131/200, Loss: 0.3566
# Epoch 132/200, Loss: 0.3454
# Epoch 133/200, Loss: 0.4171
# Epoch 134/200, Loss: 0.5388
# Epoch 135/200, Loss: 0.3644
# Epoch 136/200, Loss: 0.5353
# Epoch 137/200, Loss: 0.3154
# Epoch 138/200, Loss: 0.3522
# Epoch 139/200, Loss: 0.3752
# Epoch 140/200, Loss: 0.3416
# Epoch 141/200, Loss: 0.3770
# Epoch 142/200, Loss: 0.3927
# Epoch 143/200, Loss: 0.3069
# Epoch 144/200, Loss: 0.3973
# Epoch 145/200, Loss: 0.3132
# Epoch 146/200, Loss: 0.4577
# Epoch 147/200, Loss: 0.5085
# Epoch 148/200, Loss: 0.3801
# Epoch 149/200, Loss: 0.2757
# Epoch 150/200, Loss: 0.3232
# Epoch 151/200, Loss: 0.4834
# Epoch 152/200, Loss: 0.3365
# Epoch 153/200, Loss: 0.3787
# Epoch 154/200, Loss: 0.4694
# Epoch 155/200, Loss: 0.4614
# Epoch 156/200, Loss: 0.3879
# Epoch 157/200, Loss: 0.3390
# Epoch 158/200, Loss: 0.2928
# Epoch 159/200, Loss: 0.4401
# Epoch 160/200, Loss: 0.3391
# Epoch 161/200, Loss: 0.3752
# Epoch 162/200, Loss: 0.3412
# Epoch 163/200, Loss: 0.3126
# Epoch 164/200, Loss: 0.3807
# Epoch 165/200, Loss: 0.3608
# Epoch 166/200, Loss: 0.3703
# Epoch 167/200, Loss: 0.4360
# Epoch 168/200, Loss: 0.4021
# Epoch 169/200, Loss: 0.3228
# Epoch 170/200, Loss: 0.3567
# Epoch 171/200, Loss: 0.3209
# Epoch 172/200, Loss: 0.2332
# Epoch 173/200, Loss: 0.2983
# Epoch 174/200, Loss: 0.3452
# Epoch 175/200, Loss: 0.4437
# Epoch 176/200, Loss: 0.3415
# Epoch 177/200, Loss: 0.3778
# Epoch 178/200, Loss: 0.2770
# Epoch 179/200, Loss: 0.4647
# Epoch 180/200, Loss: 0.4548
# Epoch 181/200, Loss: 0.4511
# Epoch 182/200, Loss: 0.2460
# Epoch 183/200, Loss: 0.4138
# Epoch 184/200, Loss: 0.3349
# Epoch 185/200, Loss: 0.2222
# Epoch 186/200, Loss: 0.3032
# Epoch 187/200, Loss: 0.2779
# Epoch 188/200, Loss: 0.3107
# Epoch 189/200, Loss: 0.2868
# Epoch 190/200, Loss: 0.3003
# Epoch 191/200, Loss: 0.4432
# Epoch 192/200, Loss: 0.3039
# Epoch 193/200, Loss: 0.2871
# Epoch 194/200, Loss: 0.3748
# Epoch 195/200, Loss: 0.3043
# Epoch 196/200, Loss: 0.3040
# Epoch 197/200, Loss: 0.2563
# Epoch 198/200, Loss: 0.3993
# Epoch 199/200, Loss: 0.4022
# Epoch 200/200, Loss: 0.3136
# Moi: RMSE=3.678, R2=0.691, RPIQ=1.661
# NDF: RMSE=4.475, R2=0.336, RPIQ=1.534
# Starch: RMSE=6.686, R2=0.515, RPIQ=1.314
#
# --- Fold 4/5 ---
# Epoch 1/200, Loss: 0.9347
# Epoch 2/200, Loss: 1.1228
# Epoch 3/200, Loss: 1.0581
# Epoch 4/200, Loss: 0.9030
# Epoch 5/200, Loss: 0.9139
# Epoch 6/200, Loss: 0.8879
# Epoch 7/200, Loss: 0.9678
# Epoch 8/200, Loss: 1.1835
# Epoch 9/200, Loss: 1.0812
# Epoch 10/200, Loss: 0.9477
# Epoch 11/200, Loss: 1.1764
# Epoch 12/200, Loss: 1.0395
# Epoch 13/200, Loss: 1.0091
# Epoch 14/200, Loss: 0.8715
# Epoch 15/200, Loss: 0.9712
# Epoch 16/200, Loss: 0.9898
# Epoch 17/200, Loss: 0.8968
# Epoch 18/200, Loss: 0.7951
# Epoch 19/200, Loss: 0.7059
# Epoch 20/200, Loss: 0.8785
# Epoch 21/200, Loss: 0.8418
# Epoch 22/200, Loss: 0.5940
# Epoch 23/200, Loss: 0.6164
# Epoch 24/200, Loss: 0.5078
# Epoch 25/200, Loss: 0.5787
# Epoch 26/200, Loss: 0.6010
# Epoch 27/200, Loss: 0.5574
# Epoch 28/200, Loss: 0.6331
# Epoch 29/200, Loss: 0.6667
# Epoch 30/200, Loss: 0.4819
# Epoch 31/200, Loss: 0.5709
# Epoch 32/200, Loss: 0.6191
# Epoch 33/200, Loss: 0.5747
# Epoch 34/200, Loss: 0.5481
# Epoch 35/200, Loss: 0.7934
# Epoch 36/200, Loss: 0.6804
# Epoch 37/200, Loss: 0.6440
# Epoch 38/200, Loss: 0.5264
# Epoch 39/200, Loss: 0.4399
# Epoch 40/200, Loss: 0.5029
# Epoch 41/200, Loss: 0.6785
# Epoch 42/200, Loss: 0.6706
# Epoch 43/200, Loss: 0.6426
# Epoch 44/200, Loss: 0.6192
# Epoch 45/200, Loss: 0.7205
# Epoch 46/200, Loss: 0.5164
# Epoch 47/200, Loss: 0.4983
# Epoch 48/200, Loss: 0.6088
# Epoch 49/200, Loss: 0.4112
# Epoch 50/200, Loss: 0.5277
# Epoch 51/200, Loss: 0.5130
# Epoch 52/200, Loss: 0.5530
# Epoch 53/200, Loss: 0.5738
# Epoch 54/200, Loss: 0.6725
# Epoch 55/200, Loss: 0.5670
# Epoch 56/200, Loss: 0.4934
# Epoch 57/200, Loss: 0.6543
# Epoch 58/200, Loss: 0.4226
# Epoch 59/200, Loss: 0.4895
# Epoch 60/200, Loss: 0.5096
# Epoch 61/200, Loss: 0.4280
# Epoch 62/200, Loss: 0.5118
# Epoch 63/200, Loss: 0.4536
# Epoch 64/200, Loss: 0.5738
# Epoch 65/200, Loss: 0.5829
# Epoch 66/200, Loss: 0.5015
# Epoch 67/200, Loss: 0.5602
# Epoch 68/200, Loss: 0.4486
# Epoch 69/200, Loss: 0.4857
# Epoch 70/200, Loss: 0.5689
# Epoch 71/200, Loss: 0.5084
# Epoch 72/200, Loss: 0.4545
# Epoch 73/200, Loss: 0.4059
# Epoch 74/200, Loss: 0.4842
# Epoch 75/200, Loss: 0.4406
# Epoch 76/200, Loss: 0.5626
# Epoch 77/200, Loss: 0.5509
# Epoch 78/200, Loss: 0.4785
# Epoch 79/200, Loss: 0.4859
# Epoch 80/200, Loss: 0.4217
# Epoch 81/200, Loss: 0.5472
# Epoch 82/200, Loss: 0.4699
# Epoch 83/200, Loss: 0.4246
# Epoch 84/200, Loss: 0.4280
# Epoch 85/200, Loss: 0.5474
# Epoch 86/200, Loss: 0.4491
# Epoch 87/200, Loss: 0.5234
# Epoch 88/200, Loss: 0.4468
# Epoch 89/200, Loss: 0.3521
# Epoch 90/200, Loss: 0.6132
# Epoch 91/200, Loss: 0.3443
# Epoch 92/200, Loss: 0.4431
# Epoch 93/200, Loss: 0.4329
# Epoch 94/200, Loss: 0.3510
# Epoch 95/200, Loss: 0.4626
# Epoch 96/200, Loss: 0.4214
# Epoch 97/200, Loss: 0.3859
# Epoch 98/200, Loss: 0.4812
# Epoch 99/200, Loss: 0.3878
# Epoch 100/200, Loss: 0.4366
# Epoch 101/200, Loss: 0.5781
# Epoch 102/200, Loss: 0.4776
# Epoch 103/200, Loss: 0.4635
# Epoch 104/200, Loss: 0.5373
# Epoch 105/200, Loss: 0.4147
# Epoch 106/200, Loss: 0.4135
# Epoch 107/200, Loss: 0.4658
# Epoch 108/200, Loss: 0.4994
# Epoch 109/200, Loss: 0.4899
# Epoch 110/200, Loss: 0.4772
# Epoch 111/200, Loss: 0.4694
# Epoch 112/200, Loss: 0.4284
# Epoch 113/200, Loss: 0.4340
# Epoch 114/200, Loss: 0.4630
# Epoch 115/200, Loss: 0.4387
# Epoch 116/200, Loss: 0.4375
# Epoch 117/200, Loss: 0.4501
# Epoch 118/200, Loss: 0.4433
# Epoch 119/200, Loss: 0.5376
# Epoch 120/200, Loss: 0.3813
# Epoch 121/200, Loss: 0.3247
# Epoch 122/200, Loss: 0.5330
# Epoch 123/200, Loss: 0.4941
# Epoch 124/200, Loss: 0.3517
# Epoch 125/200, Loss: 0.3601
# Epoch 126/200, Loss: 0.4777
# Epoch 127/200, Loss: 0.4782
# Epoch 128/200, Loss: 0.4310
# Epoch 129/200, Loss: 0.4220
# Epoch 130/200, Loss: 0.3178
# Epoch 131/200, Loss: 0.4254
# Epoch 132/200, Loss: 0.4832
# Epoch 133/200, Loss: 0.3932
# Epoch 134/200, Loss: 0.3613
# Epoch 135/200, Loss: 0.4389
# Epoch 136/200, Loss: 0.4292
# Epoch 137/200, Loss: 0.4163
# Epoch 138/200, Loss: 0.4324
# Epoch 139/200, Loss: 0.3739
# Epoch 140/200, Loss: 0.4591
# Epoch 141/200, Loss: 0.3118
# Epoch 142/200, Loss: 0.3028
# Epoch 143/200, Loss: 0.4156
# Epoch 144/200, Loss: 0.4000
# Epoch 145/200, Loss: 0.4435
# Epoch 146/200, Loss: 0.4973
# Epoch 147/200, Loss: 0.3569
# Epoch 148/200, Loss: 0.4763
# Epoch 149/200, Loss: 0.3057
# Epoch 150/200, Loss: 0.3676
# Epoch 151/200, Loss: 0.2869
# Epoch 152/200, Loss: 0.4007
# Epoch 153/200, Loss: 0.4427
# Epoch 154/200, Loss: 0.3198
# Epoch 155/200, Loss: 0.3478
# Epoch 156/200, Loss: 0.3278
# Epoch 157/200, Loss: 0.3912
# Epoch 158/200, Loss: 0.4379
# Epoch 159/200, Loss: 0.4010
# Epoch 160/200, Loss: 0.3990
# Epoch 161/200, Loss: 0.3369
# Epoch 162/200, Loss: 0.5484
# Epoch 163/200, Loss: 0.3831
# Epoch 164/200, Loss: 0.3795
# Epoch 165/200, Loss: 0.4586
# Epoch 166/200, Loss: 0.3819
# Epoch 167/200, Loss: 0.3554
# Epoch 168/200, Loss: 0.3634
# Epoch 169/200, Loss: 0.3974
# Epoch 170/200, Loss: 0.3339
# Epoch 171/200, Loss: 0.3602
# Epoch 172/200, Loss: 0.2563
# Epoch 173/200, Loss: 0.3904
# Epoch 174/200, Loss: 0.3442
# Epoch 175/200, Loss: 0.2955
# Epoch 176/200, Loss: 0.4544
# Epoch 177/200, Loss: 0.4094
# Epoch 178/200, Loss: 0.3194
# Epoch 179/200, Loss: 0.4702
# Epoch 180/200, Loss: 0.3819
# Epoch 181/200, Loss: 0.3002
# Epoch 182/200, Loss: 0.3737
# Epoch 183/200, Loss: 0.3753
# Epoch 184/200, Loss: 0.3754
# Epoch 185/200, Loss: 0.3418
# Epoch 186/200, Loss: 0.2524
# Epoch 187/200, Loss: 0.3691
# Epoch 188/200, Loss: 0.4595
# Epoch 189/200, Loss: 0.3678
# Epoch 190/200, Loss: 0.3440
# Epoch 191/200, Loss: 0.3671
# Epoch 192/200, Loss: 0.3581
# Epoch 193/200, Loss: 0.2698
# Epoch 194/200, Loss: 0.3626
# Epoch 195/200, Loss: 0.3454
# Epoch 196/200, Loss: 0.3427
# Epoch 197/200, Loss: 0.3286
# Epoch 198/200, Loss: 0.3112
# Epoch 199/200, Loss: 0.4714
# Epoch 200/200, Loss: 0.3362
# Moi: RMSE=3.157, R2=0.682, RPIQ=2.258
# NDF: RMSE=6.603, R2=0.179, RPIQ=0.962
# Starch: RMSE=6.614, R2=0.479, RPIQ=1.630
#
# --- Fold 5/5 ---
# Epoch 1/200, Loss: 0.8393
# Epoch 2/200, Loss: 0.8386
# Epoch 3/200, Loss: 0.7641
# Epoch 4/200, Loss: 0.8539
# Epoch 5/200, Loss: 1.3741
# Epoch 6/200, Loss: 0.6891
# Epoch 7/200, Loss: 0.8557
# Epoch 8/200, Loss: 1.0575
# Epoch 9/200, Loss: 0.7861
# Epoch 10/200, Loss: 0.9951
# Epoch 11/200, Loss: 1.1911
# Epoch 12/200, Loss: 0.7957
# Epoch 13/200, Loss: 0.9342
# Epoch 14/200, Loss: 0.8724
# Epoch 15/200, Loss: 0.7157
# Epoch 16/200, Loss: 0.7972
# Epoch 17/200, Loss: 1.1949
# Epoch 18/200, Loss: 0.7287
# Epoch 19/200, Loss: 0.8763
# Epoch 20/200, Loss: 0.9986
# Epoch 21/200, Loss: 1.0028
# Epoch 22/200, Loss: 0.8860
# Epoch 23/200, Loss: 0.8599
# Epoch 24/200, Loss: 0.8477
# Epoch 25/200, Loss: 0.6809
# Epoch 26/200, Loss: 0.9395
# Epoch 27/200, Loss: 0.7916
# Epoch 28/200, Loss: 0.8867
# Epoch 29/200, Loss: 1.1118
# Epoch 30/200, Loss: 0.5754
# Epoch 31/200, Loss: 0.7725
# Epoch 32/200, Loss: 0.7558
# Epoch 33/200, Loss: 0.5522
# Epoch 34/200, Loss: 0.7007
# Epoch 35/200, Loss: 0.6081
# Epoch 36/200, Loss: 0.6330
# Epoch 37/200, Loss: 0.5847
# Epoch 38/200, Loss: 0.9597
# Epoch 39/200, Loss: 0.7939
# Epoch 40/200, Loss: 0.7243
# Epoch 41/200, Loss: 0.6426
# Epoch 42/200, Loss: 0.6590
# Epoch 43/200, Loss: 0.5047
# Epoch 44/200, Loss: 0.5209
# Epoch 45/200, Loss: 0.5528
# Epoch 46/200, Loss: 1.0417
# Epoch 47/200, Loss: 0.6746
# Epoch 48/200, Loss: 0.6691
# Epoch 49/200, Loss: 0.8578
# Epoch 50/200, Loss: 0.5293
# Epoch 51/200, Loss: 0.6365
# Epoch 52/200, Loss: 0.5296
# Epoch 53/200, Loss: 0.6943
# Epoch 54/200, Loss: 0.5332
# Epoch 55/200, Loss: 0.6163
# Epoch 56/200, Loss: 0.5187
# Epoch 57/200, Loss: 0.5322
# Epoch 58/200, Loss: 0.5400
# Epoch 59/200, Loss: 0.5163
# Epoch 60/200, Loss: 0.4484
# Epoch 61/200, Loss: 0.6652
# Epoch 62/200, Loss: 0.4922
# Epoch 63/200, Loss: 0.4668
# Epoch 64/200, Loss: 0.4858
# Epoch 65/200, Loss: 0.5816
# Epoch 66/200, Loss: 0.5219
# Epoch 67/200, Loss: 0.4676
# Epoch 68/200, Loss: 0.4387
# Epoch 69/200, Loss: 0.4089
# Epoch 70/200, Loss: 0.6805
# Epoch 71/200, Loss: 0.4805
# Epoch 72/200, Loss: 0.3521
# Epoch 73/200, Loss: 0.5280
# Epoch 74/200, Loss: 0.6114
# Epoch 75/200, Loss: 0.7866
# Epoch 76/200, Loss: 0.7953
# Epoch 77/200, Loss: 0.6053
# Epoch 78/200, Loss: 0.4675
# Epoch 79/200, Loss: 0.4306
# Epoch 80/200, Loss: 0.7578
# Epoch 81/200, Loss: 0.4392
# Epoch 82/200, Loss: 0.4130
# Epoch 83/200, Loss: 0.5745
# Epoch 84/200, Loss: 0.4495
# Epoch 85/200, Loss: 0.3933
# Epoch 86/200, Loss: 0.7331
# Epoch 87/200, Loss: 0.7265
# Epoch 88/200, Loss: 0.3598
# Epoch 89/200, Loss: 0.3671
# Epoch 90/200, Loss: 0.8244
# Epoch 91/200, Loss: 0.4415
# Epoch 92/200, Loss: 0.4628
# Epoch 93/200, Loss: 0.4994
# Epoch 94/200, Loss: 0.4534
# Epoch 95/200, Loss: 0.5310
# Epoch 96/200, Loss: 0.3421
# Epoch 97/200, Loss: 0.6225
# Epoch 98/200, Loss: 0.4732
# Epoch 99/200, Loss: 0.4716
# Epoch 100/200, Loss: 0.5419
# Epoch 101/200, Loss: 0.3337
# Epoch 102/200, Loss: 0.4496
# Epoch 103/200, Loss: 0.4436
# Epoch 104/200, Loss: 0.7479
# Epoch 105/200, Loss: 0.6756
# Epoch 106/200, Loss: 0.5876
# Epoch 107/200, Loss: 0.4256
# Epoch 108/200, Loss: 0.3651
# Epoch 109/200, Loss: 0.4017
# Epoch 110/200, Loss: 0.6030
# Epoch 111/200, Loss: 0.2835
# Epoch 112/200, Loss: 0.3708
# Epoch 113/200, Loss: 0.6092
# Epoch 114/200, Loss: 0.5534
# Epoch 115/200, Loss: 0.3264
# Epoch 116/200, Loss: 0.3575
# Epoch 117/200, Loss: 0.4061
# Epoch 118/200, Loss: 0.4098
# Epoch 119/200, Loss: 0.4937
# Epoch 120/200, Loss: 0.3506
# Epoch 121/200, Loss: 0.3977
# Epoch 122/200, Loss: 0.4314
# Epoch 123/200, Loss: 0.3399
# Epoch 124/200, Loss: 0.3134
# Epoch 125/200, Loss: 0.5324
# Epoch 126/200, Loss: 0.3624
# Epoch 127/200, Loss: 0.3198
# Epoch 128/200, Loss: 0.4513
# Epoch 129/200, Loss: 0.5072
# Epoch 130/200, Loss: 0.6802
# Epoch 131/200, Loss: 0.5689
# Epoch 132/200, Loss: 0.5788
# Epoch 133/200, Loss: 0.4277
# Epoch 134/200, Loss: 0.3522
# Epoch 135/200, Loss: 0.6645
# Epoch 136/200, Loss: 0.3919
# Epoch 137/200, Loss: 0.6078
# Epoch 138/200, Loss: 0.5886
# Epoch 139/200, Loss: 0.3094
# Epoch 140/200, Loss: 0.6016
# Epoch 141/200, Loss: 0.4014
# Epoch 142/200, Loss: 0.6230
# Epoch 143/200, Loss: 0.4013
# Epoch 144/200, Loss: 0.3699
# Epoch 145/200, Loss: 0.5591
# Epoch 146/200, Loss: 0.3558
# Epoch 147/200, Loss: 0.3205
# Epoch 148/200, Loss: 0.3310
# Epoch 149/200, Loss: 0.4040
# Epoch 150/200, Loss: 0.2709
# Epoch 151/200, Loss: 0.2792
# Epoch 152/200, Loss: 0.2963
# Epoch 153/200, Loss: 0.3261
# Epoch 154/200, Loss: 0.5259
# Epoch 155/200, Loss: 0.4036
# Epoch 156/200, Loss: 0.4651
# Epoch 157/200, Loss: 0.2976
# Epoch 158/200, Loss: 0.3132
# Epoch 159/200, Loss: 0.6527
# Epoch 160/200, Loss: 0.4058
# Epoch 161/200, Loss: 0.3853
# Epoch 162/200, Loss: 0.4643
# Epoch 163/200, Loss: 0.4435
# Epoch 164/200, Loss: 0.2734
# Epoch 165/200, Loss: 0.4163
# Epoch 166/200, Loss: 0.3993
# Epoch 167/200, Loss: 0.3613
# Epoch 168/200, Loss: 0.2773
# Epoch 169/200, Loss: 0.4867
# Epoch 170/200, Loss: 0.2689
# Epoch 171/200, Loss: 0.3313
# Epoch 172/200, Loss: 0.3571
# Epoch 173/200, Loss: 0.3324
# Epoch 174/200, Loss: 0.2987
# Epoch 175/200, Loss: 0.3044
# Epoch 176/200, Loss: 0.3508
# Epoch 177/200, Loss: 0.6233
# Epoch 178/200, Loss: 0.5346
# Epoch 179/200, Loss: 0.3603
# Epoch 180/200, Loss: 0.4792
# Epoch 181/200, Loss: 0.2739
# Epoch 182/200, Loss: 0.3617
# Epoch 183/200, Loss: 0.2661
# Epoch 184/200, Loss: 0.3493
# Epoch 185/200, Loss: 0.2443
# Epoch 186/200, Loss: 0.4097
# Epoch 187/200, Loss: 0.2966
# Epoch 188/200, Loss: 0.3079
# Epoch 189/200, Loss: 0.3409
# Epoch 190/200, Loss: 0.5049
# Epoch 191/200, Loss: 0.2280
# Epoch 192/200, Loss: 0.2943
# Epoch 193/200, Loss: 0.2885
# Epoch 194/200, Loss: 0.4828
# Epoch 195/200, Loss: 0.3061
# Epoch 196/200, Loss: 0.2514
# Epoch 197/200, Loss: 0.3067
# Epoch 198/200, Loss: 0.2573
# Epoch 199/200, Loss: 0.3106
# Epoch 200/200, Loss: 0.3025
# Moi: RMSE=3.295, R2=0.731, RPIQ=2.159
# NDF: RMSE=4.413, R2=0.541, RPIQ=1.586
# Starch: RMSE=6.805, R2=0.607, RPIQ=1.511

# %%
# ====== Calculate mean of the metrics obtained in each fold in CV ======

# Lists to store metrics for each fold
all_fold_metrics = {target: {"RMSE": [], "R2": [], "RPIQ": []} for target in TARGETS}

# ... (rest of the code from the previous cell for the CV loop)
# After computing metrics for each fold:
for i, t in enumerate(TARGETS):
     print(f"{t}: RMSE={metrics[i]['RMSE']:.3f}, R2={metrics[i]['R2']:.3f}, RPIQ={metrics[i]['RPIQ']:.3f}")
     all_fold_metrics[t]["RMSE"].append(metrics[i]["RMSE"])
     all_fold_metrics[t]["R2"].append(metrics[i]["R2"])
     all_fold_metrics[t]["RPIQ"].append(metrics[i]["RPIQ"])
# Out:
# Moi: RMSE=3.295, R2=0.731, RPIQ=2.159
# NDF: RMSE=4.413, R2=0.541, RPIQ=1.586
# Starch: RMSE=6.805, R2=0.607, RPIQ=1.511

# %%
# ====== Train final on all trainval + test evaluation ======
# Create data loaders for training and testing
final_loader = DataLoader(Subset(dataset, trainval_idx), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(Subset(dataset, test_idx), batch_size=batch_size, shuffle=False)

# Initialize the model, optimizer, and loss function
final_model = CNN2D().to(device)  # Move model to the specified device (GPU or CPU)
optimizer = torch.optim.Adam(final_model.parameters(), lr=lr)  # Adam optimizer
criterion = nn.MSELoss()  # Mean Squared Error loss for regression tasks

# Start training for a specified number of epochs
for epoch in range(epochs):
    final_model.train()  # Set the model to training mode (enables dropout, batchnorm, etc.)

    # Initialize variables to track loss during this epoch
    epoch_loss = 0.0  # Track cumulative loss for the current epoch

    # Iterate over the batches in the training dataset
    for xb, yb in final_loader:
        xb, yb = xb.to(device), yb.to(device)  # Move data to the specified device (GPU or CPU)

        optimizer.zero_grad()  # Clear the previous gradients
        loss = criterion(final_model(xb), yb)  # Compute the loss for this batch
        loss.backward()  # Backpropagate the gradients
        optimizer.step()  # Update the model's parameters

        epoch_loss += loss.item()  # Accumulate loss for this batch

    # Print progress after each epoch
    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss / len(final_loader):.4f}")

# Evaluate the model on the test dataset
final_model.eval()  # Set the model to evaluation mode (disables dropout, batchnorm)
y_true, y_pred = [], []  # Initialize lists to store true and predicted values

with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in test_loader:
        preds = final_model(xb.to(device)).cpu().numpy()  # Get predictions from the model
        yb_np = yb.cpu().numpy()  # Get true values from the batch

        # Reverse scaling (if applicable) to get the original values
        preds_orig = y_scaler.inverse_transform(preds)
        yb_orig = y_scaler.inverse_transform(yb_np)

        y_true.append(yb_orig)  # Append true values to the list
        y_pred.append(preds_orig)  # Append predicted values to the list

# Convert the lists to numpy arrays for metric computation
y_true, y_pred = np.vstack(y_true), np.vstack(y_pred)

# Compute the evaluation metrics (RMSE, R2, RPIQ) for the test set
test_metrics = compute_metrics_orig(y_true, y_pred)

# Print the metrics for each target
print("\n== Test metrics ==")
for i, t in enumerate(TARGETS):
    print(f"{t}: RMSE={test_metrics[i]['RMSE']:.3f}, R2={test_metrics[i]['R2']:.3f}, RPIQ={test_metrics[i]['RPIQ']:.3f}")

# Save the trained model to a file with a dynamic name
file_path = f"/content/{plot_name}_images_ready.pth"
torch.save(final_model.state_dict(), file_path)  # Save the model's state dictionary
print(f"Saved model to {file_path}")
# Out:
# Epoch 1/200, Train Loss: 0.9441
# Epoch 2/200, Train Loss: 0.9560
# Epoch 3/200, Train Loss: 0.9696
# Epoch 4/200, Train Loss: 0.9755
# Epoch 5/200, Train Loss: 0.9693
# Epoch 6/200, Train Loss: 0.9819
# Epoch 7/200, Train Loss: 0.9593
# Epoch 8/200, Train Loss: 0.9573
# Epoch 9/200, Train Loss: 0.9634
# Epoch 10/200, Train Loss: 0.9743
# Epoch 11/200, Train Loss: 0.9556
# Epoch 12/200, Train Loss: 0.9706
# Epoch 13/200, Train Loss: 0.9753
# Epoch 14/200, Train Loss: 0.9709
# Epoch 15/200, Train Loss: 0.9493
# Epoch 16/200, Train Loss: 1.0095
# Epoch 17/200, Train Loss: 0.9545
# Epoch 18/200, Train Loss: 0.9480
# Epoch 19/200, Train Loss: 0.9581
# Epoch 20/200, Train Loss: 0.9618
# Epoch 21/200, Train Loss: 0.9692
# Epoch 22/200, Train Loss: 0.9438
# Epoch 23/200, Train Loss: 0.9055
# Epoch 24/200, Train Loss: 0.8615
# Epoch 25/200, Train Loss: 0.8073
# Epoch 26/200, Train Loss: 0.7870
# Epoch 27/200, Train Loss: 0.7057
# Epoch 28/200, Train Loss: 0.7002
# Epoch 29/200, Train Loss: 0.6798
# Epoch 30/200, Train Loss: 0.6604
# Epoch 31/200, Train Loss: 0.6833
# Epoch 32/200, Train Loss: 0.6517
# Epoch 33/200, Train Loss: 0.6642
# Epoch 34/200, Train Loss: 0.6184
# Epoch 35/200, Train Loss: 0.6266
# Epoch 36/200, Train Loss: 0.6238
# Epoch 37/200, Train Loss: 0.5851
# Epoch 38/200, Train Loss: 0.6291
# Epoch 39/200, Train Loss: 0.5706
# Epoch 40/200, Train Loss: 0.5631
# Epoch 41/200, Train Loss: 0.5582
# Epoch 42/200, Train Loss: 0.5550
# Epoch 43/200, Train Loss: 0.5562
# Epoch 44/200, Train Loss: 0.5422
# Epoch 45/200, Train Loss: 0.5298
# Epoch 46/200, Train Loss: 0.5412
# Epoch 47/200, Train Loss: 0.5373
# Epoch 48/200, Train Loss: 0.5178
# Epoch 49/200, Train Loss: 0.5436
# Epoch 50/200, Train Loss: 0.5244
# Epoch 51/200, Train Loss: 0.5435
# Epoch 52/200, Train Loss: 0.5328
# Epoch 53/200, Train Loss: 0.5631
# Epoch 54/200, Train Loss: 0.5444
# Epoch 55/200, Train Loss: 0.5397
# Epoch 56/200, Train Loss: 0.5218
# Epoch 57/200, Train Loss: 0.5007
# Epoch 58/200, Train Loss: 0.5035
# Epoch 59/200, Train Loss: 0.5085
# Epoch 60/200, Train Loss: 0.4969
# Epoch 61/200, Train Loss: 0.5246
# Epoch 62/200, Train Loss: 0.4952
# Epoch 63/200, Train Loss: 0.4916
# Epoch 64/200, Train Loss: 0.4738
# Epoch 65/200, Train Loss: 0.5059
# Epoch 66/200, Train Loss: 0.5040
# Epoch 67/200, Train Loss: 0.5319
# Epoch 68/200, Train Loss: 0.5168
# Epoch 69/200, Train Loss: 0.5018
# Epoch 70/200, Train Loss: 0.4809
# Epoch 71/200, Train Loss: 0.4808
# Epoch 72/200, Train Loss: 0.4516
# Epoch 73/200, Train Loss: 0.4497
# Epoch 74/200, Train Loss: 0.4729
# Epoch 75/200, Train Loss: 0.4447
# Epoch 76/200, Train Loss: 0.4622
# Epoch 77/200, Train Loss: 0.4468
# Epoch 78/200, Train Loss: 0.4503
# Epoch 79/200, Train Loss: 0.4546
# Epoch 80/200, Train Loss: 0.4404
# Epoch 81/200, Train Loss: 0.4604
# Epoch 82/200, Train Loss: 0.4501
# Epoch 83/200, Train Loss: 0.4686
# Epoch 84/200, Train Loss: 0.4594
# Epoch 85/200, Train Loss: 0.4543
# Epoch 86/200, Train Loss: 0.4610
# Epoch 87/200, Train Loss: 0.4631
# Epoch 88/200, Train Loss: 0.4284
# Epoch 89/200, Train Loss: 0.4330
# Epoch 90/200, Train Loss: 0.4566
# Epoch 91/200, Train Loss: 0.4494
# Epoch 92/200, Train Loss: 0.4459
# Epoch 93/200, Train Loss: 0.4080
# Epoch 94/200, Train Loss: 0.4050
# Epoch 95/200, Train Loss: 0.4118
# Epoch 96/200, Train Loss: 0.4096
# Epoch 97/200, Train Loss: 0.4107
# Epoch 98/200, Train Loss: 0.4040
# Epoch 99/200, Train Loss: 0.4223
# Epoch 100/200, Train Loss: 0.4044
# Epoch 101/200, Train Loss: 0.3989
# Epoch 102/200, Train Loss: 0.3923
# Epoch 103/200, Train Loss: 0.3937
# Epoch 104/200, Train Loss: 0.4052
# Epoch 105/200, Train Loss: 0.3895
# Epoch 106/200, Train Loss: 0.4109
# Epoch 107/200, Train Loss: 0.3746
# Epoch 108/200, Train Loss: 0.3777
# Epoch 109/200, Train Loss: 0.3893
# Epoch 110/200, Train Loss: 0.3640
# Epoch 111/200, Train Loss: 0.3810
# Epoch 112/200, Train Loss: 0.3913
# Epoch 113/200, Train Loss: 0.3745
# Epoch 114/200, Train Loss: 0.3807
# Epoch 115/200, Train Loss: 0.4051
# Epoch 116/200, Train Loss: 0.3769
# Epoch 117/200, Train Loss: 0.3687
# Epoch 118/200, Train Loss: 0.3664
# Epoch 119/200, Train Loss: 0.3758
# Epoch 120/200, Train Loss: 0.3752
# Epoch 121/200, Train Loss: 0.3652
# Epoch 122/200, Train Loss: 0.3775
# Epoch 123/200, Train Loss: 0.3750
# Epoch 124/200, Train Loss: 0.3687
# Epoch 125/200, Train Loss: 0.3770
# Epoch 126/200, Train Loss: 0.3624
# Epoch 127/200, Train Loss: 0.3517
# Epoch 128/200, Train Loss: 0.3723
# Epoch 129/200, Train Loss: 0.3934
# Epoch 130/200, Train Loss: 0.3855
# Epoch 131/200, Train Loss: 0.3866
# Epoch 132/200, Train Loss: 0.3872
# Epoch 133/200, Train Loss: 0.3677
# Epoch 134/200, Train Loss: 0.3654
# Epoch 135/200, Train Loss: 0.3507
# Epoch 136/200, Train Loss: 0.3453
# Epoch 137/200, Train Loss: 0.3584
# Epoch 138/200, Train Loss: 0.3391
# Epoch 139/200, Train Loss: 0.3489
# Epoch 140/200, Train Loss: 0.3579
# Epoch 141/200, Train Loss: 0.3580
# Epoch 142/200, Train Loss: 0.3565
# Epoch 143/200, Train Loss: 0.3645
# Epoch 144/200, Train Loss: 0.3748
# Epoch 145/200, Train Loss: 0.3541
# Epoch 146/200, Train Loss: 0.3424
# Epoch 147/200, Train Loss: 0.3501
# Epoch 148/200, Train Loss: 0.3674
# Epoch 149/200, Train Loss: 0.3552
# Epoch 150/200, Train Loss: 0.3496
# Epoch 151/200, Train Loss: 0.3730
# Epoch 152/200, Train Loss: 0.3645
# Epoch 153/200, Train Loss: 0.3442
# Epoch 154/200, Train Loss: 0.3656
# Epoch 155/200, Train Loss: 0.3820
# Epoch 156/200, Train Loss: 0.3557
# Epoch 157/200, Train Loss: 0.3521
# Epoch 158/200, Train Loss: 0.3452
# Epoch 159/200, Train Loss: 0.3629
# Epoch 160/200, Train Loss: 0.3426
# Epoch 161/200, Train Loss: 0.3466
# Epoch 162/200, Train Loss: 0.3684
# Epoch 163/200, Train Loss: 0.3485
# Epoch 164/200, Train Loss: 0.3647
# Epoch 165/200, Train Loss: 0.3361
# Epoch 166/200, Train Loss: 0.3312
# Epoch 167/200, Train Loss: 0.3411
# Epoch 168/200, Train Loss: 0.3599
# Epoch 169/200, Train Loss: 0.3508
# Epoch 170/200, Train Loss: 0.3469
# Epoch 171/200, Train Loss: 0.3284
# Epoch 172/200, Train Loss: 0.3649
# Epoch 173/200, Train Loss: 0.3375
# Epoch 174/200, Train Loss: 0.3347
# Epoch 175/200, Train Loss: 0.3378
# Epoch 176/200, Train Loss: 0.3274
# Epoch 177/200, Train Loss: 0.3284
# Epoch 178/200, Train Loss: 0.3417
# Epoch 179/200, Train Loss: 0.3171
# Epoch 180/200, Train Loss: 0.3065
# Epoch 181/200, Train Loss: 0.3194
# Epoch 182/200, Train Loss: 0.3273
# Epoch 183/200, Train Loss: 0.3539
# Epoch 184/200, Train Loss: 0.3550
# Epoch 185/200, Train Loss: 0.3243
# Epoch 186/200, Train Loss: 0.3313
# Epoch 187/200, Train Loss: 0.3296
# Epoch 188/200, Train Loss: 0.3289
# Epoch 189/200, Train Loss: 0.3248
# Epoch 190/200, Train Loss: 0.3283
# Epoch 191/200, Train Loss: 0.3351
# Epoch 192/200, Train Loss: 0.3255
# Epoch 193/200, Train Loss: 0.3124
# Epoch 194/200, Train Loss: 0.3116
# Epoch 195/200, Train Loss: 0.3393
# Epoch 196/200, Train Loss: 0.3348
# Epoch 197/200, Train Loss: 0.3121
# Epoch 198/200, Train Loss: 0.3145
# Epoch 199/200, Train Loss: 0.3119
# Epoch 200/200, Train Loss: 0.3043
#
# == Test metrics ==
# Moi: RMSE=3.892, R2=0.714, RPIQ=1.821
# NDF: RMSE=5.171, R2=0.304, RPIQ=1.513
# Starch: RMSE=7.620, R2=0.459, RPIQ=1.479
# Saved model to /content/sample_images_ready.pth
