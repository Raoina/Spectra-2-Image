# %% [markdown]
# # 2D-CNN pipeline (images ready)

# %%
# ====== Imports ======
import os, random
import numpy as np
import pandas as pd
from scipy.stats import iqr
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# ====== Colab drive mount ======
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-2723259509.py in <cell line: 0>()
#       1 # ====== Colab drive mount ======
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import zipfile

# Path to the zip file in Colab
zip_file_path = '/content/spider_plots.zip'

# Directory to extract to
extract_to = '/content/SPs/'

# Unzipping the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"File unzipped to {extract_to}")
# Out:
# File unzipped to /content/SPs/

# %%
# ====== Paths ======
IMG_DIR = "/content/SPs"
CSV_PATH = "/content/train_df_averaged.csv"

TARGETS = ['Moi','NDF',  'Starch']
IMG_SIZE = 65 #------------------------------------------>16

# %%
# ====== Hyperparams ======
batch_size = 128
epochs = 200
lr = 0.0001
n_splits = 5
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
# ====== Load CSV ======
df = pd.read_csv(CSV_PATH)
# df = df.groupby('Sample ID').mean() # If the data is not averaged
# df = df.dropna(subset=TARGETS).reset_index(drop=True)
print("Data shape:", df.shape)
# Out:
# Data shape: (784, 261)

# %%
# ====== Scale targets ======
from sklearn.preprocessing import StandardScaler
# y_scaler = MinMaxScaler()
y_scaler = StandardScaler() # => Auto scale
targets_scaled = y_scaler.fit_transform(df[TARGETS].values.astype(np.float32))

# %%
plot_name = "spider_plot"  # Change this based on the plot type

# %%
# ====== Dataset class (images already ready) ======

class SoilImageDataset(Dataset):
    def __init__(self, df, img_dir, targets_scaled, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.targets = targets_scaled.astype(np.float32)
        self.transform = transform if transform else transforms.ToTensor()

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, f"{plot_name}_{idx}.png")
        img = Image.open(img_path).resize((IMG_SIZE, IMG_SIZE))  # grayscale
        img = self.transform(img)  # shape (1,H,W)
        target = torch.from_numpy(self.targets[idx])
        return img, target

transform = transforms.Compose([
    transforms.ToTensor(),  # (H,W) -> (1,H,W), float in [0,1]
])

dataset = SoilImageDataset(df, IMG_DIR, targets_scaled, transform=transform)
print("Dataset length:", len(dataset))
# Out:
# Dataset length: 784

# %% [markdown]
# I`m gonna experiment 1st with Grayscale on CV
#
# #Then RGB

# %%
# ====== CNN model (as in Table 2) ======
class CNN2D(nn.Module):
    def __init__(self, in_channels=3, num_outputs=3): # Changed num_outputs to 3
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3a = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, 3, padding=1)
        self.conv4a = nn.Conv2d(256, 512, 3, padding=1)
        self.conv4b = nn.Conv2d(512, 512, 3, padding=1)
        self.conv5a = nn.Conv2d(512, 512, 3, padding=1)
        self.conv5b = nn.Conv2d(512, 512, 3, padding=1)

        self.flattened = 512 * 2 * 2
        self.fc1 = nn.Linear(self.flattened, 128)
        self.fc2 = nn.Linear(128, num_outputs)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x)); x = self.pool(x)
        x = self.relu(self.conv2(x)); x = self.pool(x)
        x = self.relu(self.conv3a(x)); x = self.relu(self.conv3b(x)); x = self.pool(x)
        x = self.relu(self.conv4a(x)); x = self.relu(self.conv4b(x)); x = self.pool(x)
        x = self.relu(self.conv5a(x)); x = self.relu(self.conv5b(x)); x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        return self.fc2(x)

# %%
# %pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (1.5.1)

# %%
# ====== Model Summary ======
from torchsummary import summary
# Instantiate the model
model_summary = CNN2D().to(device)

# Print the model summary
print("Model Summary:")
summary(model_summary, input_size=(3, IMG_SIZE, IMG_SIZE)) # Assuming input is grayscale (1 channel)

# Print the number of parameters
num_params = sum(p.numel() for p in model_summary.parameters() if p.requires_grad)
print(f"\nNumber of parameters: {num_params}")
# Out:
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 65, 65]           1,792
#               ReLU-2           [-1, 64, 65, 65]               0
#          MaxPool2d-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 32, 32]          73,856
#               ReLU-5          [-1, 128, 32, 32]               0
#          MaxPool2d-6          [-1, 128, 16, 16]               0
#             Conv2d-7          [-1, 256, 16, 16]         295,168
#               ReLU-8          [-1, 256, 16, 16]               0
#             Conv2d-9          [-1, 256, 16, 16]         590,080
#              ReLU-10          [-1, 256, 16, 16]               0
#         MaxPool2d-11            [-1, 256, 8, 8]               0
#            Conv2d-12            [-1, 512, 8, 8]       1,180,160
#              ReLU-13            [-1, 512, 8, 8]               0
#            Conv2d-14            [-1, 512, 8, 8]       2,359,808
#              ReLU-15            [-1, 512, 8, 8]               0
#         MaxPool2d-16            [-1, 512, 4, 4]               0
#            Conv2d-17            [-1, 512, 4, 4]       2,359,808
#              ReLU-18            [-1, 512, 4, 4]               0
#            Conv2d-19            [-1, 512, 4, 4]       2,359,808
#              ReLU-20            [-1, 512, 4, 4]               0
#         MaxPool2d-21            [-1, 512, 2, 2]               0
#            Linear-22                  [-1, 128]         262,272
#              ReLU-23                  [-1, 128]               0
#            Linear-24                    [-1, 3]             387
# ================================================================
# Total params: 9,483,139
# Trainable params: 9,483,139
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 10.33
# Params size (MB): 36.18
# Estimated Total Size (MB): 46.55
# ----------------------------------------------------------------
#
# Number of parameters: 9483139

# %%
# ====== Metrics ======
def compute_metrics_orig(y_true, y_pred):
    results = []
    for i in range(y_true.shape[1]):
        yt, yp = y_true[:, i], y_pred[:, i]
        rmse = np.sqrt(mean_squared_error(yt, yp))
        r2 = r2_score(yt, yp)
        rpiq = float(iqr(yt) / rmse) if rmse > 1e-8 else float("inf")
        results.append({"RMSE": rmse, "R2": r2, "RPIQ": rpiq})
    return results

# %%
# ====== Split train/test ======
indices = np.arange(len(dataset))
trainval_idx, test_idx = train_test_split(indices, test_size=0.25, random_state=seed)

# %%
# ====== 5-Fold CV ====== But more Verbose
kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
for fold, (t_idx, v_idx) in enumerate(kf.split(trainval_idx)):
    print(f"\n--- Fold {fold+1}/{n_splits} ---")
    train_loader = DataLoader(Subset(dataset, trainval_idx[t_idx]), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(Subset(dataset, trainval_idx[v_idx]), batch_size=batch_size, shuffle=False)

    model = CNN2D().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    for epoch in range(epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            loss = criterion(model(xb), yb)
            loss.backward()
            optimizer.step()

        # Verbose mode
        if (epoch+1) % 1 == 0:  # This will print every epoch (verbose=2 equivalent in training)
            print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")

    # Validation
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            preds = model(xb.to(device)).cpu().numpy()
            yb_np = yb.cpu().numpy()
            preds_orig = y_scaler.inverse_transform(preds)
            yb_orig = y_scaler.inverse_transform(yb_np)
            y_true.append(yb_orig); y_pred.append(preds_orig)
    y_true, y_pred = np.vstack(y_true), np.vstack(y_pred)

    # Compute and print metrics
    metrics = compute_metrics_orig(y_true, y_pred)
    for i, t in enumerate(TARGETS):
        print(f"{t}: RMSE={metrics[i]['RMSE']:.3f}, R2={metrics[i]['R2']:.3f}, RPIQ={metrics[i]['RPIQ']:.3f}")
# Out:
# --- Fold 1/5 ---
# Epoch 1/100, Loss: 1.1221
# Epoch 2/100, Loss: 0.8388
# Epoch 3/100, Loss: 1.1384
# Epoch 4/100, Loss: 0.9702
# Epoch 5/100, Loss: 0.9403
# Epoch 6/100, Loss: 0.8286
# Epoch 7/100, Loss: 1.0344
# Epoch 8/100, Loss: 1.0219
# Epoch 9/100, Loss: 0.8753
# Epoch 10/100, Loss: 1.4952
# Epoch 11/100, Loss: 1.0310
# Epoch 12/100, Loss: 0.7568
# Epoch 13/100, Loss: 1.2121
# Epoch 14/100, Loss: 0.9335
# Epoch 15/100, Loss: 0.9789
# Epoch 16/100, Loss: 0.9108
# Epoch 17/100, Loss: 0.9121
# Epoch 18/100, Loss: 1.0057
# Epoch 19/100, Loss: 1.0687
# Epoch 20/100, Loss: 0.7762
# Epoch 21/100, Loss: 0.7351
# Epoch 22/100, Loss: 0.7385
# Epoch 23/100, Loss: 0.8654
# Epoch 24/100, Loss: 0.6992
# Epoch 25/100, Loss: 0.9706
# Epoch 26/100, Loss: 0.6838
# Epoch 27/100, Loss: 0.9048
# Epoch 28/100, Loss: 1.0692
# Epoch 29/100, Loss: 0.6192
# Epoch 30/100, Loss: 0.9026
# Epoch 31/100, Loss: 0.8715
# Epoch 32/100, Loss: 0.8911
# Epoch 33/100, Loss: 0.8515
# Epoch 34/100, Loss: 0.8059
# Epoch 35/100, Loss: 0.9232
# Epoch 36/100, Loss: 1.0161
# Epoch 37/100, Loss: 0.7956
# Epoch 38/100, Loss: 0.6102
# Epoch 39/100, Loss: 0.9677
# Epoch 40/100, Loss: 0.4601
# Epoch 41/100, Loss: 0.5524
# Epoch 42/100, Loss: 0.5786
# Epoch 43/100, Loss: 0.5252
# Epoch 44/100, Loss: 0.6563
# Epoch 45/100, Loss: 0.4705
# Epoch 46/100, Loss: 0.8129
# Epoch 47/100, Loss: 0.6320
# Epoch 48/100, Loss: 0.4446
# Epoch 49/100, Loss: 0.3972
# Epoch 50/100, Loss: 0.7712
# Epoch 51/100, Loss: 0.4148
# Epoch 52/100, Loss: 0.4904
# Epoch 53/100, Loss: 0.8243
# Epoch 54/100, Loss: 0.4459
# Epoch 55/100, Loss: 0.7409
# Epoch 56/100, Loss: 0.6618
# Epoch 57/100, Loss: 0.4512
# Epoch 58/100, Loss: 0.4565
# Epoch 59/100, Loss: 0.3942
# Epoch 60/100, Loss: 0.3993
# Epoch 61/100, Loss: 0.5000
# Epoch 62/100, Loss: 0.3655
# Epoch 63/100, Loss: 0.6638
# Epoch 64/100, Loss: 0.2897
# Epoch 65/100, Loss: 0.5913
# Epoch 66/100, Loss: 0.3530
# Epoch 67/100, Loss: 0.3251
# Epoch 68/100, Loss: 0.4381
# Epoch 69/100, Loss: 0.5884
# Epoch 70/100, Loss: 0.3034
# Epoch 71/100, Loss: 0.4364
# Epoch 72/100, Loss: 0.5804
# Epoch 73/100, Loss: 0.3761
# Epoch 74/100, Loss: 0.2732
# Epoch 75/100, Loss: 0.3718
# Epoch 76/100, Loss: 0.3201
# Epoch 77/100, Loss: 0.3228
# Epoch 78/100, Loss: 0.3450
# Epoch 79/100, Loss: 0.3026
# Epoch 80/100, Loss: 0.3322
# Epoch 81/100, Loss: 0.5863
# Epoch 82/100, Loss: 0.2958
# Epoch 83/100, Loss: 0.3376
# Epoch 84/100, Loss: 0.2389
# Epoch 85/100, Loss: 0.2474
# Epoch 86/100, Loss: 0.3319
# Epoch 87/100, Loss: 0.2506
# Epoch 88/100, Loss: 0.2633
# Epoch 89/100, Loss: 0.3260
# Epoch 90/100, Loss: 0.1874
# Epoch 91/100, Loss: 0.2860
# Epoch 92/100, Loss: 0.3102
# Epoch 93/100, Loss: 0.6598
# Epoch 94/100, Loss: 0.5624
# Epoch 95/100, Loss: 0.2875
# Epoch 96/100, Loss: 0.2683
# Epoch 97/100, Loss: 0.5478
# Epoch 98/100, Loss: 0.2397
# Epoch 99/100, Loss: 0.2407
# Epoch 100/100, Loss: 0.4808
# Moi: RMSE=3.174, R2=0.747, RPIQ=2.135
# NDF: RMSE=4.143, R2=0.552, RPIQ=2.086
# Starch: RMSE=5.671, R2=0.688, RPIQ=1.916
#
# --- Fold 2/5 ---
# Epoch 1/100, Loss: 1.0289
# Epoch 2/100, Loss: 0.8018
# Epoch 3/100, Loss: 1.1423
# Epoch 4/100, Loss: 0.8234
# Epoch 5/100, Loss: 1.0215
# Epoch 6/100, Loss: 1.1522
# Epoch 7/100, Loss: 0.9724
# Epoch 8/100, Loss: 0.9970
# Epoch 9/100, Loss: 0.8369
# Epoch 10/100, Loss: 0.9567
# Epoch 11/100, Loss: 0.9780
# Epoch 12/100, Loss: 1.0809
# Epoch 13/100, Loss: 0.9908
# Epoch 14/100, Loss: 1.1673
# Epoch 15/100, Loss: 1.1490
# Epoch 16/100, Loss: 1.2360
# Epoch 17/100, Loss: 0.8453
# Epoch 18/100, Loss: 0.8179
# Epoch 19/100, Loss: 0.8123
# Epoch 20/100, Loss: 0.8618
# Epoch 21/100, Loss: 1.2015
# Epoch 22/100, Loss: 0.9816
# Epoch 23/100, Loss: 1.2440
# Epoch 24/100, Loss: 0.8989
# Epoch 25/100, Loss: 0.8370
# Epoch 26/100, Loss: 0.6569
# Epoch 27/100, Loss: 0.9554
# Epoch 28/100, Loss: 0.7074
# Epoch 29/100, Loss: 0.8825
# Epoch 30/100, Loss: 1.1200
# Epoch 31/100, Loss: 0.7141
# Epoch 32/100, Loss: 0.8737
# Epoch 33/100, Loss: 1.0215
# Epoch 34/100, Loss: 0.8867
# Epoch 35/100, Loss: 0.5723
# Epoch 36/100, Loss: 0.9093
# Epoch 37/100, Loss: 0.8050
# Epoch 38/100, Loss: 0.7262
# Epoch 39/100, Loss: 0.7656
# Epoch 40/100, Loss: 0.8339
# Epoch 41/100, Loss: 0.6507
# Epoch 42/100, Loss: 0.6412
# Epoch 43/100, Loss: 0.6411
# Epoch 44/100, Loss: 0.4949
# Epoch 45/100, Loss: 0.6147
# Epoch 46/100, Loss: 0.8242
# Epoch 47/100, Loss: 0.6990
# Epoch 48/100, Loss: 0.5349
# Epoch 49/100, Loss: 0.3741
# Epoch 50/100, Loss: 0.4879
# Epoch 51/100, Loss: 0.4555
# Epoch 52/100, Loss: 0.4194
# Epoch 53/100, Loss: 0.6725
# Epoch 54/100, Loss: 0.6962
# Epoch 55/100, Loss: 0.4292
# Epoch 56/100, Loss: 0.4046
# Epoch 57/100, Loss: 0.6315
# Epoch 58/100, Loss: 0.3764
# Epoch 59/100, Loss: 0.4403
# Epoch 60/100, Loss: 0.4192
# Epoch 61/100, Loss: 0.3183
# Epoch 62/100, Loss: 0.3609
# Epoch 63/100, Loss: 0.3449
# Epoch 64/100, Loss: 0.3673
# Epoch 65/100, Loss: 0.3004
# Epoch 66/100, Loss: 0.3610
# Epoch 67/100, Loss: 0.3813
# Epoch 68/100, Loss: 0.3700
# Epoch 69/100, Loss: 0.3199
# Epoch 70/100, Loss: 0.2335
# Epoch 71/100, Loss: 0.3685
# Epoch 72/100, Loss: 0.3642
# Epoch 73/100, Loss: 0.5906
# Epoch 74/100, Loss: 0.3308
# Epoch 75/100, Loss: 0.2767
# Epoch 76/100, Loss: 0.2601
# Epoch 77/100, Loss: 0.2684
# Epoch 78/100, Loss: 0.2578
# Epoch 79/100, Loss: 0.3317
# Epoch 80/100, Loss: 0.2431
# Epoch 81/100, Loss: 0.3163
# Epoch 82/100, Loss: 0.3102
# Epoch 83/100, Loss: 0.2508
# Epoch 84/100, Loss: 0.6323
# Epoch 85/100, Loss: 0.2341
# Epoch 86/100, Loss: 0.2402
# Epoch 87/100, Loss: 0.2518
# Epoch 88/100, Loss: 0.2476
# Epoch 89/100, Loss: 0.2618
# Epoch 90/100, Loss: 0.2045
# Epoch 91/100, Loss: 0.2788
# Epoch 92/100, Loss: 0.3570
# Epoch 93/100, Loss: 0.2304
# Epoch 94/100, Loss: 0.2462
# Epoch 95/100, Loss: 0.2631
# Epoch 96/100, Loss: 0.2919
# Epoch 97/100, Loss: 0.5672
# Epoch 98/100, Loss: 0.2826
# Epoch 99/100, Loss: 0.2391
# Epoch 100/100, Loss: 0.1717
# Moi: RMSE=2.730, R2=0.766, RPIQ=2.829
# NDF: RMSE=4.027, R2=0.542, RPIQ=1.988
# Starch: RMSE=6.564, R2=0.544, RPIQ=1.606
#
# --- Fold 3/5 ---
# Epoch 1/100, Loss: 0.9618
# Epoch 2/100, Loss: 0.8038
# Epoch 3/100, Loss: 1.0806
# Epoch 4/100, Loss: 1.3135
# Epoch 5/100, Loss: 0.7116
# Epoch 6/100, Loss: 0.9909
# Epoch 7/100, Loss: 0.9502
# Epoch 8/100, Loss: 1.1538
# Epoch 9/100, Loss: 1.0040
# Epoch 10/100, Loss: 1.1160
# Epoch 11/100, Loss: 0.9532
# Epoch 12/100, Loss: 1.4408
# Epoch 13/100, Loss: 0.9380
# Epoch 14/100, Loss: 0.8407
# Epoch 15/100, Loss: 0.6386
# Epoch 16/100, Loss: 0.8815
# Epoch 17/100, Loss: 1.0285
# Epoch 18/100, Loss: 0.8689
# Epoch 19/100, Loss: 1.1509
# Epoch 20/100, Loss: 0.7891
# Epoch 21/100, Loss: 0.8342
# Epoch 22/100, Loss: 1.0792
# Epoch 23/100, Loss: 0.8747
# Epoch 24/100, Loss: 0.7850
# Epoch 25/100, Loss: 0.8854
# Epoch 26/100, Loss: 0.7696
# Epoch 27/100, Loss: 0.7933
# Epoch 28/100, Loss: 0.7817
# Epoch 29/100, Loss: 0.6673
# Epoch 30/100, Loss: 0.7150
# Epoch 31/100, Loss: 0.9417
# Epoch 32/100, Loss: 0.8860
# Epoch 33/100, Loss: 0.4846
# Epoch 34/100, Loss: 0.4983
# Epoch 35/100, Loss: 0.4905
# Epoch 36/100, Loss: 0.3771
# Epoch 37/100, Loss: 0.4274
# Epoch 38/100, Loss: 0.4948
# Epoch 39/100, Loss: 0.3958
# Epoch 40/100, Loss: 0.4528
# Epoch 41/100, Loss: 0.3909
# Epoch 42/100, Loss: 0.3788
# Epoch 43/100, Loss: 0.5120
# Epoch 44/100, Loss: 0.6429
# Epoch 45/100, Loss: 0.7375
# Epoch 46/100, Loss: 0.4476
# Epoch 47/100, Loss: 0.5130
# Epoch 48/100, Loss: 0.3620
# Epoch 49/100, Loss: 0.4111
# Epoch 50/100, Loss: 0.3670
# Epoch 51/100, Loss: 0.4187
# Epoch 52/100, Loss: 0.3159
# Epoch 53/100, Loss: 0.6596
# Epoch 54/100, Loss: 0.3519
# Epoch 55/100, Loss: 0.4486
# Epoch 56/100, Loss: 0.3336
# Epoch 57/100, Loss: 0.3705
# Epoch 58/100, Loss: 0.4306
# Epoch 59/100, Loss: 0.2823
# Epoch 60/100, Loss: 0.3316
# Epoch 61/100, Loss: 0.3952
# Epoch 62/100, Loss: 0.3582
# Epoch 63/100, Loss: 0.5273
# Epoch 64/100, Loss: 0.6043
# Epoch 65/100, Loss: 0.5421
# Epoch 66/100, Loss: 0.3565
# Epoch 67/100, Loss: 0.3395
# Epoch 68/100, Loss: 0.3264
# Epoch 69/100, Loss: 0.3133
# Epoch 70/100, Loss: 0.3971
# Epoch 71/100, Loss: 0.2792
# Epoch 72/100, Loss: 0.3802
# Epoch 73/100, Loss: 0.3645
# Epoch 74/100, Loss: 0.2548
# Epoch 75/100, Loss: 0.6108
# Epoch 76/100, Loss: 0.3011
# Epoch 77/100, Loss: 0.2870
# Epoch 78/100, Loss: 0.3284
# Epoch 79/100, Loss: 0.2802
# Epoch 80/100, Loss: 0.3429
# Epoch 81/100, Loss: 0.2765
# Epoch 82/100, Loss: 0.3008
# Epoch 83/100, Loss: 0.5109
# Epoch 84/100, Loss: 0.2456
# Epoch 85/100, Loss: 0.4619
# Epoch 86/100, Loss: 0.2950
# Epoch 87/100, Loss: 0.2738
# Epoch 88/100, Loss: 0.2423
# Epoch 89/100, Loss: 0.2159
# Epoch 90/100, Loss: 0.2811
# Epoch 91/100, Loss: 0.2740
# Epoch 92/100, Loss: 0.3028
# Epoch 93/100, Loss: 0.2365
# Epoch 94/100, Loss: 0.2972
# Epoch 95/100, Loss: 0.5076
# Epoch 96/100, Loss: 0.2016
# Epoch 97/100, Loss: 0.2336
# Epoch 98/100, Loss: 0.2630
# Epoch 99/100, Loss: 0.2088
# Epoch 100/100, Loss: 0.2638
# Moi: RMSE=2.564, R2=0.850, RPIQ=2.383
# NDF: RMSE=3.685, R2=0.550, RPIQ=1.863
# Starch: RMSE=5.589, R2=0.661, RPIQ=1.572
#
# --- Fold 4/5 ---
# Epoch 1/100, Loss: 0.8960
# Epoch 2/100, Loss: 0.8111
# Epoch 3/100, Loss: 1.0532
# Epoch 4/100, Loss: 0.8283
# Epoch 5/100, Loss: 0.9609
# Epoch 6/100, Loss: 0.8507
# Epoch 7/100, Loss: 0.9783
# Epoch 8/100, Loss: 0.9104
# Epoch 9/100, Loss: 0.9182
# Epoch 10/100, Loss: 0.9254
# Epoch 11/100, Loss: 0.7147
# Epoch 12/100, Loss: 1.0420
# Epoch 13/100, Loss: 0.9159
# Epoch 14/100, Loss: 1.2152
# Epoch 15/100, Loss: 0.9129
# Epoch 16/100, Loss: 0.9965
# Epoch 17/100, Loss: 1.0372
# Epoch 18/100, Loss: 1.1625
# Epoch 19/100, Loss: 0.9541
# Epoch 20/100, Loss: 0.9093
# Epoch 21/100, Loss: 0.8217
# Epoch 22/100, Loss: 0.9880
# Epoch 23/100, Loss: 0.7778
# Epoch 24/100, Loss: 0.9177
# Epoch 25/100, Loss: 0.8653
# Epoch 26/100, Loss: 0.9156
# Epoch 27/100, Loss: 0.6363
# Epoch 28/100, Loss: 0.6713
# Epoch 29/100, Loss: 0.6532
# Epoch 30/100, Loss: 0.7845
# Epoch 31/100, Loss: 0.7362
# Epoch 32/100, Loss: 0.5374
# Epoch 33/100, Loss: 0.6510
# Epoch 34/100, Loss: 0.7306
# Epoch 35/100, Loss: 0.5803
# Epoch 36/100, Loss: 0.6724
# Epoch 37/100, Loss: 0.4346
# Epoch 38/100, Loss: 0.5127
# Epoch 39/100, Loss: 0.5138
# Epoch 40/100, Loss: 0.5190
# Epoch 41/100, Loss: 0.5517
# Epoch 42/100, Loss: 0.5159
# Epoch 43/100, Loss: 0.5078
# Epoch 44/100, Loss: 0.3578
# Epoch 45/100, Loss: 0.4747
# Epoch 46/100, Loss: 0.5503
# Epoch 47/100, Loss: 0.4010
# Epoch 48/100, Loss: 0.4929
# Epoch 49/100, Loss: 0.4014
# Epoch 50/100, Loss: 0.4111
# Epoch 51/100, Loss: 0.4623
# Epoch 52/100, Loss: 0.3665
# Epoch 53/100, Loss: 0.3900
# Epoch 54/100, Loss: 0.3758
# Epoch 55/100, Loss: 0.5004
# Epoch 56/100, Loss: 0.3800
# Epoch 57/100, Loss: 0.4807
# Epoch 58/100, Loss: 0.5491
# Epoch 59/100, Loss: 0.3100
# Epoch 60/100, Loss: 0.2992
# Epoch 61/100, Loss: 0.2913
# Epoch 62/100, Loss: 0.3846
# Epoch 63/100, Loss: 0.2868
# Epoch 64/100, Loss: 0.3336
# Epoch 65/100, Loss: 0.4283
# Epoch 66/100, Loss: 0.4270
# Epoch 67/100, Loss: 0.3086
# Epoch 68/100, Loss: 0.2850
# Epoch 69/100, Loss: 0.3509
# Epoch 70/100, Loss: 0.3889
# Epoch 71/100, Loss: 0.2428
# Epoch 72/100, Loss: 0.3403
# Epoch 73/100, Loss: 0.2826
# Epoch 74/100, Loss: 0.3248
# Epoch 75/100, Loss: 0.2645
# Epoch 76/100, Loss: 0.2905
# Epoch 77/100, Loss: 0.2415
# Epoch 78/100, Loss: 0.2578
# Epoch 79/100, Loss: 0.2518
# Epoch 80/100, Loss: 0.2238
# Epoch 81/100, Loss: 0.2804
# Epoch 82/100, Loss: 0.2648
# Epoch 83/100, Loss: 0.2197
# Epoch 84/100, Loss: 0.3197
# Epoch 85/100, Loss: 0.3164
# Epoch 86/100, Loss: 0.2464
# Epoch 87/100, Loss: 0.2511
# Epoch 88/100, Loss: 0.2659
# Epoch 89/100, Loss: 0.2786
# Epoch 90/100, Loss: 0.3010
# Epoch 91/100, Loss: 0.2315
# Epoch 92/100, Loss: 0.2329
# Epoch 93/100, Loss: 0.2030
# Epoch 94/100, Loss: 0.2501
# Epoch 95/100, Loss: 0.2639
# Epoch 96/100, Loss: 0.3129
# Epoch 97/100, Loss: 0.2060
# Epoch 98/100, Loss: 0.1965
# Epoch 99/100, Loss: 0.2214
# Epoch 100/100, Loss: 0.2175
# Moi: RMSE=2.709, R2=0.766, RPIQ=2.632
# NDF: RMSE=6.180, R2=0.281, RPIQ=1.027
# Starch: RMSE=6.656, R2=0.473, RPIQ=1.620
#
# --- Fold 5/5 ---
# Epoch 1/100, Loss: 1.0896
# Epoch 2/100, Loss: 0.7746
# Epoch 3/100, Loss: 0.7935
# Epoch 4/100, Loss: 0.8694
# Epoch 5/100, Loss: 0.9758
# Epoch 6/100, Loss: 0.7367
# Epoch 7/100, Loss: 0.6654
# Epoch 8/100, Loss: 1.1417
# Epoch 9/100, Loss: 1.0730
# Epoch 10/100, Loss: 0.8505
# Epoch 11/100, Loss: 0.9253
# Epoch 12/100, Loss: 0.8643
# Epoch 13/100, Loss: 1.1873
# Epoch 14/100, Loss: 1.0354
# Epoch 15/100, Loss: 0.8263
# Epoch 16/100, Loss: 1.2459
# Epoch 17/100, Loss: 0.7147
# Epoch 18/100, Loss: 1.0469
# Epoch 19/100, Loss: 0.8987
# Epoch 20/100, Loss: 0.6814
# Epoch 21/100, Loss: 0.9434
# Epoch 22/100, Loss: 1.0564
# Epoch 23/100, Loss: 0.6744
# Epoch 24/100, Loss: 0.9511
# Epoch 25/100, Loss: 0.7440
# Epoch 26/100, Loss: 0.7965
# Epoch 27/100, Loss: 0.6765
# Epoch 28/100, Loss: 0.5825
# Epoch 29/100, Loss: 1.0094
# Epoch 30/100, Loss: 0.7929
# Epoch 31/100, Loss: 0.6530
# Epoch 32/100, Loss: 0.9872
# Epoch 33/100, Loss: 0.7725
# Epoch 34/100, Loss: 0.8436
# Epoch 35/100, Loss: 0.4767
# Epoch 36/100, Loss: 0.7467
# Epoch 37/100, Loss: 0.7695
# Epoch 38/100, Loss: 0.6011
# Epoch 39/100, Loss: 0.6239
# Epoch 40/100, Loss: 0.5045
# Epoch 41/100, Loss: 0.4415
# Epoch 42/100, Loss: 0.4353
# Epoch 43/100, Loss: 0.4207
# Epoch 44/100, Loss: 0.3467
# Epoch 45/100, Loss: 0.3730
# Epoch 46/100, Loss: 0.4347
# Epoch 47/100, Loss: 0.3050
# Epoch 48/100, Loss: 0.3716
# Epoch 49/100, Loss: 0.6599
# Epoch 50/100, Loss: 0.4563
# Epoch 51/100, Loss: 0.4322
# Epoch 52/100, Loss: 0.3722
# Epoch 53/100, Loss: 0.4166
# Epoch 54/100, Loss: 0.4145
# Epoch 55/100, Loss: 0.4261
# Epoch 56/100, Loss: 0.3661
# Epoch 57/100, Loss: 0.3885
# Epoch 58/100, Loss: 0.4122
# Epoch 59/100, Loss: 0.4658
# Epoch 60/100, Loss: 0.3760
# Epoch 61/100, Loss: 0.5559
# Epoch 62/100, Loss: 0.6227
# Epoch 63/100, Loss: 0.3074
# Epoch 64/100, Loss: 0.5476
# Epoch 65/100, Loss: 0.3341
# Epoch 66/100, Loss: 0.2546
# Epoch 67/100, Loss: 0.2931
# Epoch 68/100, Loss: 0.3212
# Epoch 69/100, Loss: 0.3297
# Epoch 70/100, Loss: 0.3737
# Epoch 71/100, Loss: 0.3146
# Epoch 72/100, Loss: 0.3022
# Epoch 73/100, Loss: 0.3167
# Epoch 74/100, Loss: 0.3031
# Epoch 75/100, Loss: 0.2703
# Epoch 76/100, Loss: 0.5414
# Epoch 77/100, Loss: 0.3292
# Epoch 78/100, Loss: 0.3067
# Epoch 79/100, Loss: 0.6819
# Epoch 80/100, Loss: 0.2460
# Epoch 81/100, Loss: 0.2972
# Epoch 82/100, Loss: 0.2832
# Epoch 83/100, Loss: 0.2258
# Epoch 84/100, Loss: 0.3073
# Epoch 85/100, Loss: 0.2558
# Epoch 86/100, Loss: 0.2502
# Epoch 87/100, Loss: 0.3386
# Epoch 88/100, Loss: 0.2214
# Epoch 89/100, Loss: 0.2525
# Epoch 90/100, Loss: 0.5099
# Epoch 91/100, Loss: 0.4654
# Epoch 92/100, Loss: 0.2179
# Epoch 93/100, Loss: 0.6061
# Epoch 94/100, Loss: 0.3436
# Epoch 95/100, Loss: 0.2749
# Epoch 96/100, Loss: 0.5144
# Epoch 97/100, Loss: 0.3420
# Epoch 98/100, Loss: 0.2668
# Epoch 99/100, Loss: 0.2682
# Epoch 100/100, Loss: 0.2385
# Moi: RMSE=2.735, R2=0.815, RPIQ=2.601
# NDF: RMSE=4.073, R2=0.609, RPIQ=1.719
# Starch: RMSE=6.686, R2=0.620, RPIQ=1.538

# %%
# ====== Calculate mean of the metrics obtained in each fold in CV ======

# Lists to store metrics for each fold
all_fold_metrics = {target: {"RMSE": [], "R2": [], "RPIQ": []} for target in TARGETS}

# ... (rest of the code from the previous cell for the CV loop)
# After computing metrics for each fold:
for i, t in enumerate(TARGETS):
     print(f"{t}: RMSE={metrics[i]['RMSE']:.3f}, R2={metrics[i]['R2']:.3f}, RPIQ={metrics[i]['RPIQ']:.3f}")
     all_fold_metrics[t]["RMSE"].append(metrics[i]["RMSE"])
     all_fold_metrics[t]["R2"].append(metrics[i]["R2"])
     all_fold_metrics[t]["RPIQ"].append(metrics[i]["RPIQ"])
# Out:
# Moi: RMSE=2.735, R2=0.815, RPIQ=2.601
# NDF: RMSE=4.073, R2=0.609, RPIQ=1.719
# Starch: RMSE=6.686, R2=0.620, RPIQ=1.538

# %%
# ====== Train final on all trainval + test evaluation ======
# Create data loaders for training and testing
final_loader = DataLoader(Subset(dataset, trainval_idx), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(Subset(dataset, test_idx), batch_size=batch_size, shuffle=False)

# Initialize the model, optimizer, and loss function
final_model = CNN2D().to(device)  # Move model to the specified device (GPU or CPU)
optimizer = torch.optim.Adam(final_model.parameters(), lr=lr)  # Adam optimizer
criterion = nn.MSELoss()  # Mean Squared Error loss for regression tasks

# Start training for a specified number of epochs
for epoch in range(epochs):
    final_model.train()  # Set the model to training mode (enables dropout, batchnorm, etc.)

    # Initialize variables to track loss during this epoch
    epoch_loss = 0.0  # Track cumulative loss for the current epoch

    # Iterate over the batches in the training dataset
    for xb, yb in final_loader:
        xb, yb = xb.to(device), yb.to(device)  # Move data to the specified device (GPU or CPU)

        optimizer.zero_grad()  # Clear the previous gradients
        loss = criterion(final_model(xb), yb)  # Compute the loss for this batch
        loss.backward()  # Backpropagate the gradients
        optimizer.step()  # Update the model's parameters

        epoch_loss += loss.item()  # Accumulate loss for this batch

    # Print progress after each epoch
    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss / len(final_loader):.4f}")

# Evaluate the model on the test dataset
final_model.eval()  # Set the model to evaluation mode (disables dropout, batchnorm)
y_true, y_pred = [], []  # Initialize lists to store true and predicted values

with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in test_loader:
        preds = final_model(xb.to(device)).cpu().numpy()  # Get predictions from the model
        yb_np = yb.cpu().numpy()  # Get true values from the batch

        # Reverse scaling (if applicable) to get the original values
        preds_orig = y_scaler.inverse_transform(preds)
        yb_orig = y_scaler.inverse_transform(yb_np)

        y_true.append(yb_orig)  # Append true values to the list
        y_pred.append(preds_orig)  # Append predicted values to the list

# Convert the lists to numpy arrays for metric computation
y_true, y_pred = np.vstack(y_true), np.vstack(y_pred)

# Compute the evaluation metrics (RMSE, R2, RPIQ) for the test set
test_metrics = compute_metrics_orig(y_true, y_pred)

# Print the metrics for each target
print("\n== Test metrics ==")
for i, t in enumerate(TARGETS):
    print(f"{t}: RMSE={test_metrics[i]['RMSE']:.3f}, R2={test_metrics[i]['R2']:.3f}, RPIQ={test_metrics[i]['RPIQ']:.3f}")

# Save the trained model to a file with a dynamic name
file_path = f"/content/{plot_name}_images_ready.pth"
torch.save(final_model.state_dict(), file_path)  # Save the model's state dictionary
print(f"Saved model to {file_path}")
# Out:
# Epoch 1/200, Train Loss: 0.9758
# Epoch 2/200, Train Loss: 0.9684
# Epoch 3/200, Train Loss: 0.9658
# Epoch 4/200, Train Loss: 0.9773
# Epoch 5/200, Train Loss: 0.9620
# Epoch 6/200, Train Loss: 0.9657
# Epoch 7/200, Train Loss: 0.9758
# Epoch 8/200, Train Loss: 0.9692
# Epoch 9/200, Train Loss: 0.9649
# Epoch 10/200, Train Loss: 0.9577
# Epoch 11/200, Train Loss: 0.9759
# Epoch 12/200, Train Loss: 0.9632
# Epoch 13/200, Train Loss: 0.9937
# Epoch 14/200, Train Loss: 0.9750
# Epoch 15/200, Train Loss: 0.9503
# Epoch 16/200, Train Loss: 0.9830
# Epoch 17/200, Train Loss: 0.9572
# Epoch 18/200, Train Loss: 0.9711
# Epoch 19/200, Train Loss: 0.9621
# Epoch 20/200, Train Loss: 0.9838
# Epoch 21/200, Train Loss: 0.9363
# Epoch 22/200, Train Loss: 0.8992
# Epoch 23/200, Train Loss: 0.8715
# Epoch 24/200, Train Loss: 0.8844
# Epoch 25/200, Train Loss: 0.8786
# Epoch 26/200, Train Loss: 0.8548
# Epoch 27/200, Train Loss: 0.8296
# Epoch 28/200, Train Loss: 0.8058
# Epoch 29/200, Train Loss: 0.8109
# Epoch 30/200, Train Loss: 0.7901
# Epoch 31/200, Train Loss: 0.7732
# Epoch 32/200, Train Loss: 0.7099
# Epoch 33/200, Train Loss: 0.6712
# Epoch 34/200, Train Loss: 0.6409
# Epoch 35/200, Train Loss: 0.6144
# Epoch 36/200, Train Loss: 0.5684
# Epoch 37/200, Train Loss: 0.5699
# Epoch 38/200, Train Loss: 0.5414
# Epoch 39/200, Train Loss: 0.5091
# Epoch 40/200, Train Loss: 0.5707
# Epoch 41/200, Train Loss: 0.4961
# Epoch 42/200, Train Loss: 0.4714
# Epoch 43/200, Train Loss: 0.4505
# Epoch 44/200, Train Loss: 0.4446
# Epoch 45/200, Train Loss: 0.4733
# Epoch 46/200, Train Loss: 0.4344
# Epoch 47/200, Train Loss: 0.4063
# Epoch 48/200, Train Loss: 0.4249
# Epoch 49/200, Train Loss: 0.4054
# Epoch 50/200, Train Loss: 0.3762
# Epoch 51/200, Train Loss: 0.3910
# Epoch 52/200, Train Loss: 0.3742
# Epoch 53/200, Train Loss: 0.3631
# Epoch 54/200, Train Loss: 0.3481
# Epoch 55/200, Train Loss: 0.3527
# Epoch 56/200, Train Loss: 0.3634
# Epoch 57/200, Train Loss: 0.3580
# Epoch 58/200, Train Loss: 0.3590
# Epoch 59/200, Train Loss: 0.3516
# Epoch 60/200, Train Loss: 0.3179
# Epoch 61/200, Train Loss: 0.3196
# Epoch 62/200, Train Loss: 0.3172
# Epoch 63/200, Train Loss: 0.3122
# Epoch 64/200, Train Loss: 0.3253
# Epoch 65/200, Train Loss: 0.2964
# Epoch 66/200, Train Loss: 0.3026
# Epoch 67/200, Train Loss: 0.3186
# Epoch 68/200, Train Loss: 0.3153
# Epoch 69/200, Train Loss: 0.2936
# Epoch 70/200, Train Loss: 0.3030
# Epoch 71/200, Train Loss: 0.3055
# Epoch 72/200, Train Loss: 0.2923
# Epoch 73/200, Train Loss: 0.2810
# Epoch 74/200, Train Loss: 0.2907
# Epoch 75/200, Train Loss: 0.2810
# Epoch 76/200, Train Loss: 0.2954
# Epoch 77/200, Train Loss: 0.2755
# Epoch 78/200, Train Loss: 0.2854
# Epoch 79/200, Train Loss: 0.3034
# Epoch 80/200, Train Loss: 0.2722
# Epoch 81/200, Train Loss: 0.2608
# Epoch 82/200, Train Loss: 0.2634
# Epoch 83/200, Train Loss: 0.2811
# Epoch 84/200, Train Loss: 0.2754
# Epoch 85/200, Train Loss: 0.2636
# Epoch 86/200, Train Loss: 0.2730
# Epoch 87/200, Train Loss: 0.2498
# Epoch 88/200, Train Loss: 0.2536
# Epoch 89/200, Train Loss: 0.2558
# Epoch 90/200, Train Loss: 0.2454
# Epoch 91/200, Train Loss: 0.2514
# Epoch 92/200, Train Loss: 0.2435
# Epoch 93/200, Train Loss: 0.2616
# Epoch 94/200, Train Loss: 0.2528
# Epoch 95/200, Train Loss: 0.2948
# Epoch 96/200, Train Loss: 0.2785
# Epoch 97/200, Train Loss: 0.2621
# Epoch 98/200, Train Loss: 0.2474
# Epoch 99/200, Train Loss: 0.2414
# Epoch 100/200, Train Loss: 0.2583
# Epoch 101/200, Train Loss: 0.2673
# Epoch 102/200, Train Loss: 0.2390
# Epoch 103/200, Train Loss: 0.2873
# Epoch 104/200, Train Loss: 0.2654
# Epoch 105/200, Train Loss: 0.2631
# Epoch 106/200, Train Loss: 0.2334
# Epoch 107/200, Train Loss: 0.2379
# Epoch 108/200, Train Loss: 0.2338
# Epoch 109/200, Train Loss: 0.2289
# Epoch 110/200, Train Loss: 0.2284
# Epoch 111/200, Train Loss: 0.2342
# Epoch 112/200, Train Loss: 0.2380
# Epoch 113/200, Train Loss: 0.2267
# Epoch 114/200, Train Loss: 0.2239
# Epoch 115/200, Train Loss: 0.2405
# Epoch 116/200, Train Loss: 0.2106
# Epoch 117/200, Train Loss: 0.2124
# Epoch 118/200, Train Loss: 0.2107
# Epoch 119/200, Train Loss: 0.2134
# Epoch 120/200, Train Loss: 0.2286
# Epoch 121/200, Train Loss: 0.2241
# Epoch 122/200, Train Loss: 0.2251
# Epoch 123/200, Train Loss: 0.2244
# Epoch 124/200, Train Loss: 0.2336
# Epoch 125/200, Train Loss: 0.2391
# Epoch 126/200, Train Loss: 0.2194
# Epoch 127/200, Train Loss: 0.2051
# Epoch 128/200, Train Loss: 0.2035
# Epoch 129/200, Train Loss: 0.2053
# Epoch 130/200, Train Loss: 0.2075
# Epoch 131/200, Train Loss: 0.2052
# Epoch 132/200, Train Loss: 0.2080
# Epoch 133/200, Train Loss: 0.2258
# Epoch 134/200, Train Loss: 0.2006
# Epoch 135/200, Train Loss: 0.2156
# Epoch 136/200, Train Loss: 0.2187
# Epoch 137/200, Train Loss: 0.2019
# Epoch 138/200, Train Loss: 0.1983
# Epoch 139/200, Train Loss: 0.1935
# Epoch 140/200, Train Loss: 0.1914
# Epoch 141/200, Train Loss: 0.1905
# Epoch 142/200, Train Loss: 0.1943
# Epoch 143/200, Train Loss: 0.1916
# Epoch 144/200, Train Loss: 0.2027
# Epoch 145/200, Train Loss: 0.2082
# Epoch 146/200, Train Loss: 0.2221
# Epoch 147/200, Train Loss: 0.2149
# Epoch 148/200, Train Loss: 0.1929
# Epoch 149/200, Train Loss: 0.2199
# Epoch 150/200, Train Loss: 0.1998
# Epoch 151/200, Train Loss: 0.1945
# Epoch 152/200, Train Loss: 0.2170
# Epoch 153/200, Train Loss: 0.2183
# Epoch 154/200, Train Loss: 0.1856
# Epoch 155/200, Train Loss: 0.1990
# Epoch 156/200, Train Loss: 0.2198
# Epoch 157/200, Train Loss: 0.2043
# Epoch 158/200, Train Loss: 0.2068
# Epoch 159/200, Train Loss: 0.2166
# Epoch 160/200, Train Loss: 0.1835
# Epoch 161/200, Train Loss: 0.1938
# Epoch 162/200, Train Loss: 0.2047
# Epoch 163/200, Train Loss: 0.1916
# Epoch 164/200, Train Loss: 0.1833
# Epoch 165/200, Train Loss: 0.1880
# Epoch 166/200, Train Loss: 0.1896
# Epoch 167/200, Train Loss: 0.1865
# Epoch 168/200, Train Loss: 0.1764
# Epoch 169/200, Train Loss: 0.1855
# Epoch 170/200, Train Loss: 0.1863
# Epoch 171/200, Train Loss: 0.1985
# Epoch 172/200, Train Loss: 0.1747
# Epoch 173/200, Train Loss: 0.1810
# Epoch 174/200, Train Loss: 0.1779
# Epoch 175/200, Train Loss: 0.1858
# Epoch 176/200, Train Loss: 0.1955
# Epoch 177/200, Train Loss: 0.1809
# Epoch 178/200, Train Loss: 0.1815
# Epoch 179/200, Train Loss: 0.1759
# Epoch 180/200, Train Loss: 0.1743
# Epoch 181/200, Train Loss: 0.1725
# Epoch 182/200, Train Loss: 0.1672
# Epoch 183/200, Train Loss: 0.1666
# Epoch 184/200, Train Loss: 0.1680
# Epoch 185/200, Train Loss: 0.1622
# Epoch 186/200, Train Loss: 0.1659
# Epoch 187/200, Train Loss: 0.1856
# Epoch 188/200, Train Loss: 0.1724
# Epoch 189/200, Train Loss: 0.1647
# Epoch 190/200, Train Loss: 0.1846
# Epoch 191/200, Train Loss: 0.1956
# Epoch 192/200, Train Loss: 0.1774
# Epoch 193/200, Train Loss: 0.1655
# Epoch 194/200, Train Loss: 0.1642
# Epoch 195/200, Train Loss: 0.1594
# Epoch 196/200, Train Loss: 0.1628
# Epoch 197/200, Train Loss: 0.1822
# Epoch 198/200, Train Loss: 0.1780
# Epoch 199/200, Train Loss: 0.1697
# Epoch 200/200, Train Loss: 0.1656
#
# == Test metrics ==
# Moi: RMSE=2.565, R2=0.876, RPIQ=2.764
# NDF: RMSE=3.336, R2=0.710, RPIQ=2.346
# Starch: RMSE=4.641, R2=0.799, RPIQ=2.428
# Saved model to /content/spider_plot_images_ready.pth
